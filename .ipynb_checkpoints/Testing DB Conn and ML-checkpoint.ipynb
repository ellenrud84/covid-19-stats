# %% [markdown]
# # TESTING DB CONNECTION AND VIEWS

# %%
# Install Dependencies
import pandas as pd
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

from numpy import concatenate
from math import sqrt
from statsmodels.graphics.gofplots import qqplot
from pandas.plotting import autocorrelation_plot

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
from flask import Flask, jsonify, render_template

import json

import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from pmdarima import auto_arima 
import statsmodels.api as sm
import plotly.express as px
import plotly as py

# %%
engine = create_engine("postgres://hdsqfkpfyrmcls:44d0c2afaa4b73f05e08bd94b4604fdb7b43432e1260f0ee78d4fbf9adae54d2@ec2-34-239-241-25.compute-1.amazonaws.com:5432/ddnn9438k8o9n9", echo=False)
conn = engine.connect()

# %%
from datetime import date, timedelta

today = date.today()
today
yesterday = today - timedelta(days = 1)
yesterday
tomorrow= today + timedelta(days = 1)
tomorrow
lala=today- timedelta(days=230)
lala
# Out:
# datetime.date(2020, 4, 20)

# %%
# ALABAMA STATE DATA:
queries_alabama_state_cases= pd.read_sql(f"select * from states_cases where state = 'Alabama' and NOT state ISNULL and cases != 'N'",conn)
result_alabama_state_cases=queries_alabama_state_cases.to_json(orient='index')
parsed_alabama_state_cases=json.loads(result_alabama_state_cases)

queries_alabama_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Alabama' and NOT state ISNULL and deaths != 'N'",conn)
result_alabama_state_deaths=queries_alabama_state_deaths.to_json(orient='index')
parsed_alabama_state_deaths=json.loads(result_alabama_state_deaths)

# ALASKA STATE DATA:
queries_alaska_state_cases= pd.read_sql(f"select * from states_cases where state = 'Alaska' and NOT state ISNULL and cases != 'N'",conn)
result_alaska_state_cases=queries_alaska_state_cases.to_json(orient='index')
parsed_alaska_state_cases=json.loads(result_alaska_state_cases)

queries_alaska_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Alaska' and NOT state ISNULL and deaths != 'N'",conn)
result_alaska_state_deaths=queries_alaska_state_deaths.to_json(orient='index')
parsed_alaska_state_deaths=json.loads(result_alaska_state_deaths)

# ARIZONA STATE DATA:
queries_arizona_state_cases= pd.read_sql(f"select * from states_cases where state = 'Arizona' and NOT state ISNULL and cases != 'N'",conn)
result_arizona_state_cases=queries_arizona_state_cases.to_json(orient='index')
parsed_arizona_state_cases=json.loads(result_arizona_state_cases)

queries_arizona_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Arizona' and NOT state ISNULL and deaths != 'N'",conn)
result_arizona_state_deaths=queries_arizona_state_deaths.to_json(orient='index')
parsed_arizona_state_deaths=json.loads(result_arizona_state_deaths)

# ARKANSAS STATE DATA:
queries_arkansas_state_cases= pd.read_sql(f"select * from states_cases where state = 'Arkansas' and NOT state ISNULL and cases != 'N'",conn)
result_arkansas_state_cases=queries_arkansas_state_cases.to_json(orient='index')
parsed_arkansas_state_cases=json.loads(result_arkansas_state_cases)

queries_arkansas_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Arkansas' and NOT state ISNULL and deaths != 'N'",conn)
result_arkansas_state_deaths=queries_arkansas_state_deaths.to_json(orient='index')
parsed_arkansas_state_deaths=json.loads(result_arkansas_state_deaths)

# CALIFORNIA STATE DATA:
queries_california_state_cases= pd.read_sql(f"select * from states_cases where state = 'California' and NOT state ISNULL and cases != 'N'",conn)
result_california_state_cases=queries_california_state_cases.to_json(orient='index')
parsed_california_state_cases=json.loads(result_california_state_cases)

queries_california_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'California' and NOT state ISNULL and deaths != 'N'",conn)
result_california_state_deaths=queries_california_state_deaths.to_json(orient='index')
parsed_california_state_deaths=json.loads(result_california_state_deaths)

# COLORADO STATE DATA:
queries_colorado_state_cases= pd.read_sql(f"select * from states_cases where state = 'Colorado' and NOT state ISNULL and cases != 'N'",conn)
result_colorado_state_cases=queries_colorado_state_cases.to_json(orient='index')
parsed_colorado_state_cases=json.loads(result_colorado_state_cases)

queries_colorado_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Colorado' and NOT state ISNULL and deaths != 'N'",conn)
result_colorado_state_deaths=queries_colorado_state_deaths.to_json(orient='index')
parsed_colorado_state_deaths=json.loads(result_colorado_state_deaths)

# CONNECTICUT STATE DATA:
queries_connecticut_state_cases= pd.read_sql(f"select * from states_cases where state = 'Connecticut' and NOT state ISNULL and cases != 'N'",conn)
result_connecticut_state_cases=queries_connecticut_state_cases.to_json(orient='index')
parsed_connecticut_state_cases=json.loads(result_connecticut_state_cases)

queries_connecticut_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Connecticut' and NOT state ISNULL and deaths != 'N'",conn)
result_connecticut_state_deaths=queries_connecticut_state_deaths.to_json(orient='index')
parsed_connecticut_state_deaths=json.loads(result_connecticut_state_deaths)

# DELAWARE STATE DATA:
queries_delaware_state_cases= pd.read_sql(f"select * from states_cases where state = 'Delaware' and NOT state ISNULL and cases != 'N'",conn)
result_delaware_state_cases=queries_delaware_state_cases.to_json(orient='index')
parsed_delaware_state_cases=json.loads(result_delaware_state_cases)

queries_delaware_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Delaware' and NOT state ISNULL and deaths != 'N'",conn)
result_delaware_state_deaths=queries_delaware_state_deaths.to_json(orient='index')
parsed_delaware_state_deaths=json.loads(result_delaware_state_deaths)

# DISTRICT OF COLOUMBIA STATE DATA:
queries_dc_state_cases= pd.read_sql(f"select * from states_cases where state = 'District of Columbia' and NOT state ISNULL and cases != 'N'",conn)
result_dc_state_cases=queries_dc_state_cases.to_json(orient='index')
parsed_dc_state_cases=json.loads(result_dc_state_cases)

queries_dc_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'District of Columbia' and NOT state ISNULL and deaths != 'N'",conn)
result_dc_state_deaths=queries_dc_state_deaths.to_json(orient='index')
parsed_dc_state_deaths=json.loads(result_dc_state_deaths)

# FLORIDA STATE DATA:
queries_florida_state_cases= pd.read_sql(f"select * from states_cases where state = 'Florida' and NOT state ISNULL and cases != 'N'",conn)
result_florida_state_cases=queries_florida_state_cases.to_json(orient='index')
parsed_florida_state_cases=json.loads(result_florida_state_cases)

queries_florida_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Florida' and NOT state ISNULL and deaths != 'N'",conn)
result_florida_state_deaths=queries_florida_state_deaths.to_json(orient='index')
parsed_florida_state_deaths=json.loads(result_florida_state_deaths)

# GEORGIA STATE DATA:
queries_georgia_state_cases= pd.read_sql(f"select * from states_cases where state = 'Georgia' and NOT state ISNULL and cases != 'N'",conn)
result_georgia_state_cases=queries_georgia_state_cases.to_json(orient='index')
parsed_georgia_state_cases=json.loads(result_georgia_state_cases)

queries_georgia_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Georgia' and NOT state ISNULL and deaths != 'N'",conn)
result_georgia_state_deaths=queries_georgia_state_deaths.to_json(orient='index')
parsed_georgia_state_deaths=json.loads(result_georgia_state_deaths)

# GUAM STATE DATA:
queries_guam_state_cases= pd.read_sql(f"select * from states_cases where state = 'Guam' and NOT state ISNULL and cases != 'N'",conn)
result_guam_state_cases=queries_guam_state_cases.to_json(orient='index')
parsed_guam_state_cases=json.loads(result_guam_state_cases)

queries_guam_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Guam' and NOT state ISNULL and deaths != 'N'",conn)
result_guam_state_deaths=queries_guam_state_deaths.to_json(orient='index')
parsed_guam_state_deaths=json.loads(result_guam_state_deaths)

# HAWAII STATE DATA:
queries_hawaii_state_cases= pd.read_sql(f"select * from states_cases where state = 'Hawaii' and NOT state ISNULL and cases != 'N'",conn)
result_hawaii_state_cases=queries_hawaii_state_cases.to_json(orient='index')
parsed_hawaii_state_cases=json.loads(result_hawaii_state_cases)

queries_hawaii_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Hawaii' and NOT state ISNULL and deaths != 'N'",conn)
result_hawaii_state_deaths=queries_hawaii_state_deaths.to_json(orient='index')
parsed_hawaii_state_deaths=json.loads(result_hawaii_state_deaths)

# IDAHO STATE DATA:
queries_idaho_state_cases= pd.read_sql(f"select * from states_cases where state = 'Idaho' and NOT state ISNULL and cases != 'N'",conn)
result_idaho_state_cases=queries_idaho_state_cases.to_json(orient='index')
parsed_idaho_state_cases=json.loads(result_idaho_state_cases)

queries_idaho_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Idaho' and NOT state ISNULL and deaths != 'N'",conn)
result_idaho_state_deaths=queries_idaho_state_deaths.to_json(orient='index')
parsed_idaho_state_deaths=json.loads(result_idaho_state_deaths)

# ILLINOIS STATE DATA:
queries_illinois_state_cases= pd.read_sql(f"select * from states_cases where state = 'Illinois' and NOT state ISNULL and cases != 'N'",conn)
result_illinois_state_cases=queries_illinois_state_cases.to_json(orient='index')
parsed_illinois_state_cases=json.loads(result_illinois_state_cases)

queries_illinois_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Illinois' and NOT state ISNULL and deaths != 'N'",conn)
result_illinois_state_deaths=queries_illinois_state_deaths.to_json(orient='index')
parsed_illinois_state_deaths=json.loads(result_illinois_state_deaths)

# INDIANA STATE DATA:
queries_indiana_state_cases= pd.read_sql(f"select * from states_cases where state = 'Indiana' and NOT state ISNULL and cases != 'N'",conn)
result_indiana_state_cases=queries_indiana_state_cases.to_json(orient='index')
parsed_indiana_state_cases=json.loads(result_indiana_state_cases)

queries_indiana_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Indiana' and NOT state ISNULL and deaths != 'N'",conn)
result_indiana_state_deaths=queries_indiana_state_deaths.to_json(orient='index')
parsed_indiana_state_deaths=json.loads(result_indiana_state_deaths)

# IOWA STATE DATA:
queries_iowa_state_cases= pd.read_sql(f"select * from states_cases where state = 'Iowa' and NOT state ISNULL and cases != 'N'",conn)
result_iowa_state_cases=queries_iowa_state_cases.to_json(orient='index')
parsed_iowa_state_cases=json.loads(result_iowa_state_cases)

queries_iowa_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Iowa' and NOT state ISNULL and deaths != 'N'",conn)
result_iowa_state_deaths=queries_iowa_state_deaths.to_json(orient='index')
parsed_iowa_state_deaths=json.loads(result_iowa_state_deaths)

# KANSAS STATE DATA:
queries_kansas_state_cases= pd.read_sql(f"select * from states_cases where state = 'Kansas' and NOT state ISNULL and cases != 'N'",conn)
result_kansas_state_cases=queries_kansas_state_cases.to_json(orient='index')
parsed_kansas_state_cases=json.loads(result_kansas_state_cases)

queries_kansas_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Kansas' and NOT state ISNULL and deaths != 'N'",conn)
result_kansas_state_deaths=queries_kansas_state_deaths.to_json(orient='index')
parsed_kansas_state_deaths=json.loads(result_kansas_state_deaths)

# KENTUCKY STATE DATA:
queries_kentucky_state_cases= pd.read_sql(f"select * from states_cases where state = 'Kentucky' and NOT state ISNULL and cases != 'N'",conn)
result_kentucky_state_cases=queries_kentucky_state_cases.to_json(orient='index')
parsed_kentucky_state_cases=json.loads(result_kentucky_state_cases)

queries_kentucky_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Kentucky' and NOT state ISNULL and deaths != 'N'",conn)
result_kentucky_state_deaths=queries_kentucky_state_deaths.to_json(orient='index')
parsed_kentucky_state_deaths=json.loads(result_kentucky_state_deaths)

# LOUISIANA STATE DATA:
queries_louisiana_state_cases= pd.read_sql(f"select * from states_cases where state = 'Louisiana' and NOT state ISNULL and cases != 'N'",conn)
result_louisiana_state_cases=queries_louisiana_state_cases.to_json(orient='index')
parsed_louisiana_state_cases=json.loads(result_louisiana_state_cases)

queries_louisiana_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Louisiana' and NOT state ISNULL and deaths != 'N'",conn)
result_louisiana_state_deaths=queries_louisiana_state_deaths.to_json(orient='index')
parsed_louisiana_state_deaths=json.loads(result_louisiana_state_deaths)

# MAINE STATE DATA:
queries_maine_state_cases= pd.read_sql(f"select * from states_cases where state = 'Maine' and NOT state ISNULL and cases != 'N'",conn)
result_maine_state_cases=queries_maine_state_cases.to_json(orient='index')
parsed_maine_state_cases=json.loads(result_maine_state_cases)

queries_maine_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Maine' and NOT state ISNULL and deaths != 'N'",conn)
result_maine_state_deaths=queries_maine_state_deaths.to_json(orient='index')
parsed_maine_state_deaths=json.loads(result_maine_state_deaths)

# MARYLAND STATE DATA:
queries_maryland_state_cases= pd.read_sql(f"select * from states_cases where state = 'Maryland' and NOT state ISNULL and cases != 'N'",conn)
result_maryland_state_cases=queries_maryland_state_cases.to_json(orient='index')
parsed_maryland_state_cases=json.loads(result_maryland_state_cases)

queries_maryland_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Maryland' and NOT state ISNULL and deaths != 'N'",conn)
result_maryland_state_deaths=queries_maryland_state_deaths.to_json(orient='index')
parsed_maryland_state_deaths=json.loads(result_maryland_state_deaths)

# MASSACHUSETTS STATE DATA:
queries_massachusetts_state_cases= pd.read_sql(f"select * from states_cases where state = 'Massachusetts' and NOT state ISNULL and cases != 'N'",conn)
result_massachusetts_state_cases=queries_massachusetts_state_cases.to_json(orient='index')
parsed_massachusetts_state_cases=json.loads(result_massachusetts_state_cases)

queries_massachusetts_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Massachusetts' and NOT state ISNULL and deaths != 'N'",conn)
result_massachusetts_state_deaths=queries_massachusetts_state_deaths.to_json(orient='index')
parsed_massachusetts_state_deaths=json.loads(result_massachusetts_state_deaths)

# MICHIGAN STATE DATA:
queries_michigan_state_cases= pd.read_sql(f"select * from states_cases where state = 'Michigan' and NOT state ISNULL and cases != 'N'",conn)
result_michigan_state_cases=queries_michigan_state_cases.to_json(orient='index')
parsed_michigan_state_cases=json.loads(result_michigan_state_cases)

queries_michigan_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Michigan' and NOT state ISNULL and deaths != 'N'",conn)
result_michigan_state_deaths=queries_michigan_state_deaths.to_json(orient='index')
parsed_michigan_state_deaths=json.loads(result_michigan_state_deaths)

# MINNESOTA STATE DATA:
queries_minnesota_state_cases= pd.read_sql(f"select * from states_cases where state = 'Minnesota' and NOT state ISNULL and cases != 'N'",conn)
result_minnesota_state_cases=queries_minnesota_state_cases.to_json(orient='index')
parsed_minnesota_state_cases=json.loads(result_minnesota_state_cases)

queries_minnesota_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Minnesota' and NOT state ISNULL and deaths != 'N'",conn)
result_minnesota_state_deaths=queries_minnesota_state_deaths.to_json(orient='index')
parsed_minnesota_state_deaths=json.loads(result_minnesota_state_deaths)

# MISSISSIPPI STATE DATA:
queries_mississippi_state_cases= pd.read_sql(f"select * from states_cases where state = 'Mississippi' and NOT state ISNULL and cases != 'N'",conn)
result_mississippi_state_cases=queries_mississippi_state_cases.to_json(orient='index')
parsed_mississippi_state_cases=json.loads(result_mississippi_state_cases)

queries_mississippi_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Mississippi' and NOT state ISNULL and deaths != 'N'",conn)
result_mississippi_state_deaths=queries_mississippi_state_deaths.to_json(orient='index')
parsed_mississippi_state_deaths=json.loads(result_mississippi_state_deaths)

# MISSOURI STATE DATA:
queries_missouri_state_cases= pd.read_sql(f"select * from states_cases where state = 'Missouri' and NOT state ISNULL and cases != 'N'",conn)
result_missouri_state_cases=queries_missouri_state_cases.to_json(orient='index')
parsed_missouri_state_cases=json.loads(result_missouri_state_cases)

queries_missouri_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Missouri' and NOT state ISNULL and deaths != 'N'",conn)
result_missouri_state_deaths=queries_missouri_state_deaths.to_json(orient='index')
parsed_missouri_state_deaths=json.loads(result_missouri_state_deaths)

# MONTANA STATE DATA:
queries_montana_state_cases= pd.read_sql(f"select * from states_cases where state = 'Montana' and NOT state ISNULL and cases != 'N'",conn)
result_montana_state_cases=queries_montana_state_cases.to_json(orient='index')
parsed_montana_state_cases=json.loads(result_montana_state_cases)

queries_montana_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Montana' and NOT state ISNULL and deaths != 'N'",conn)
result_montana_state_deaths=queries_montana_state_deaths.to_json(orient='index')
parsed_montana_state_deaths=json.loads(result_montana_state_deaths)

# NEBRASKA STATE DATA:
queries_nebraska_state_cases= pd.read_sql(f"select * from states_cases where state = 'Nebraska' and NOT state ISNULL and cases != 'N'",conn)
result_nebraska_state_cases=queries_nebraska_state_cases.to_json(orient='index')
parsed_nebraska_state_cases=json.loads(result_nebraska_state_cases)

queries_nebraska_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Nebraska' and NOT state ISNULL and deaths != 'N'",conn)
result_nebraska_state_deaths=queries_nebraska_state_deaths.to_json(orient='index')
parsed_nebraska_state_deaths=json.loads(result_nebraska_state_deaths)

# NEVADA STATE DATA:
queries_nevada_state_cases= pd.read_sql(f"select * from states_cases where state = 'Nevada' and NOT state ISNULL and cases != 'N'",conn)
result_nevada_state_cases=queries_nevada_state_cases.to_json(orient='index')
parsed_nevada_state_cases=json.loads(result_nevada_state_cases)

queries_nevada_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Nevada' and NOT state ISNULL and deaths != 'N'",conn)
result_nevada_state_deaths=queries_nevada_state_deaths.to_json(orient='index')
parsed_nevada_state_deaths=json.loads(result_nevada_state_deaths)

# NEW HAMPSHIRE STATE DATA:
queries_new_hampshire_state_cases= pd.read_sql(f"select * from states_cases where state = 'New Hampshire' and NOT state ISNULL and cases != 'N'",conn)
result_new_hampshire_state_cases=queries_new_hampshire_state_cases.to_json(orient='index')
parsed_new_hampshire_state_cases=json.loads(result_new_hampshire_state_cases)

queries_new_hampshire_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'New Hampshire' and NOT state ISNULL and deaths != 'N'",conn)
result_new_hampshire_state_deaths=queries_new_hampshire_state_deaths.to_json(orient='index')
parsed_new_hampshire_state_deaths=json.loads(result_new_hampshire_state_deaths)

# NEW JERSEY STATE DATA:
queries_new_jersey_state_cases= pd.read_sql(f"select * from states_cases where state = 'New Jersey' and NOT state ISNULL and cases != 'N'",conn)
result_new_jersey_state_cases=queries_new_jersey_state_cases.to_json(orient='index')
parsed_new_jersey_state_cases=json.loads(result_new_jersey_state_cases)

queries_new_jersey_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'New Jersey' and NOT state ISNULL and deaths != 'N'",conn)
result_new_jersey_state_deaths=queries_new_jersey_state_deaths.to_json(orient='index')
parsed_new_jersey_state_deaths=json.loads(result_new_jersey_state_deaths)

# NEW MEXICO STATE DATA:
queries_new_mexico_state_cases= pd.read_sql(f"select * from states_cases where state = 'New Mexico' and NOT state ISNULL and cases != 'N'",conn)
result_new_mexico_state_cases=queries_new_mexico_state_cases.to_json(orient='index')
parsed_new_mexico_state_cases=json.loads(result_new_mexico_state_cases)

queries_new_mexico_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'New Mexico' and NOT state ISNULL and deaths != 'N'",conn)
result_new_mexico_state_deaths=queries_new_mexico_state_deaths.to_json(orient='index')
parsed_new_mexico_state_deaths=json.loads(result_new_mexico_state_deaths)

# NEW YORK STATE DATA:
queries_new_york_state_cases= pd.read_sql(f"select * from states_cases where state = 'New York' and NOT state ISNULL and cases != 'N'",conn)
result_new_york_state_cases=queries_new_york_state_cases.to_json(orient='index')
parsed_new_york_state_cases=json.loads(result_new_york_state_cases)

queries_new_york_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'New York' and NOT state ISNULL and deaths != 'N'",conn)
result_new_york_state_deaths=queries_new_york_state_deaths.to_json(orient='index')
parsed_new_york_state_deaths=json.loads(result_new_york_state_deaths)

# NORTH CAROLINA STATE DATA:
queries_north_carolina_state_cases= pd.read_sql(f"select * from states_cases where state = 'North Carolina' and NOT state ISNULL and cases != 'N'",conn)
result_north_carolina_state_cases=queries_north_carolina_state_cases.to_json(orient='index')
parsed_north_carolina_state_cases=json.loads(result_north_carolina_state_cases)

queries_north_carolina_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'North Carolina' and NOT state ISNULL and deaths != 'N'",conn)
result_north_carolina_state_deaths=queries_north_carolina_state_deaths.to_json(orient='index')
parsed_north_carolina_state_deaths=json.loads(result_north_carolina_state_deaths)

# NORTH DAKOTA STATE DATA:
queries_north_dakota_state_cases= pd.read_sql(f"select * from states_cases where state = 'North Dakota' and NOT state ISNULL and cases != 'N'",conn)
result_north_dakota_state_cases=queries_north_dakota_state_cases.to_json(orient='index')
parsed_north_dakota_state_cases=json.loads(result_north_dakota_state_cases)

queries_north_dakota_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'North Dakota' and NOT state ISNULL and deaths != 'N'",conn)
result_north_dakota_state_deaths=queries_north_dakota_state_deaths.to_json(orient='index')
parsed_north_dakota_state_deaths=json.loads(result_north_dakota_state_deaths)

# NORTHERN MARIANA ISLANDS STATE DATA:
queries_northern_mariana_islands_state_cases= pd.read_sql(f"select * from states_cases where state = 'Northern Mariana Islands' and NOT state ISNULL and cases != 'N'",conn)
result_northern_mariana_islands_state_cases=queries_northern_mariana_islands_state_cases.to_json(orient='index')
parsed_northern_mariana_islands_state_cases=json.loads(result_northern_mariana_islands_state_cases)

queries_northern_mariana_islands_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Northern Mariana Islands' and NOT state ISNULL and deaths != 'N'",conn)
result_northern_mariana_islands_state_deaths=queries_northern_mariana_islands_state_deaths.to_json(orient='index')
parsed_northern_mariana_islands_state_deaths=json.loads(result_northern_mariana_islands_state_deaths)

# OHIO STATE DATA:
queries_ohio_state_cases= pd.read_sql(f"select * from states_cases where state = 'Ohio' and NOT state ISNULL and cases != 'N'",conn)
result_ohio_state_cases=queries_ohio_state_cases.to_json(orient='index')
parsed_ohio_state_cases=json.loads(result_ohio_state_cases)

queries_ohio_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Ohio' and NOT state ISNULL and deaths != 'N'",conn)
result_ohio_state_deaths=queries_ohio_state_deaths.to_json(orient='index')
parsed_ohio_state_deaths=json.loads(result_ohio_state_deaths)

# OKLAHOMA STATE DATA:
queries_oklahoma_state_cases= pd.read_sql(f"select * from states_cases where state = 'Oklahoma' and NOT state ISNULL and cases != 'N'",conn)
result_oklahoma_state_cases=queries_oklahoma_state_cases.to_json(orient='index')
parsed_oklahoma_state_cases=json.loads(result_oklahoma_state_cases)

queries_oklahoma_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Oklahoma' and NOT state ISNULL and deaths != 'N'",conn)
result_oklahoma_state_deaths=queries_oklahoma_state_deaths.to_json(orient='index')
parsed_oklahoma_state_deaths=json.loads(result_oklahoma_state_deaths)

# OREGON STATE DATA:
queries_oregon_state_cases= pd.read_sql(f"select * from states_cases where state = 'Oregon' and NOT state ISNULL and cases != 'N'",conn)
result_oregon_state_cases=queries_oregon_state_cases.to_json(orient='index')
parsed_oregon_state_cases=json.loads(result_oregon_state_cases)

queries_oregon_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Oregon' and NOT state ISNULL and deaths != 'N'",conn)
result_oregon_state_deaths=queries_oregon_state_deaths.to_json(orient='index')
parsed_oregon_state_deaths=json.loads(result_oregon_state_deaths)

# PENNSYLVANIA STATE DATA:
queries_pennsylvania_state_cases= pd.read_sql(f"select * from states_cases where state = 'Pennsylvania' and NOT state ISNULL and cases != 'N'",conn)
result_pennsylvania_state_cases=queries_pennsylvania_state_cases.to_json(orient='index')
parsed_pennsylvania_state_cases=json.loads(result_pennsylvania_state_cases)

queries_pennsylvania_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Pennsylvania' and NOT state ISNULL and deaths != 'N'",conn)
result_pennsylvania_state_deaths=queries_pennsylvania_state_deaths.to_json(orient='index')
parsed_pennsylvania_state_deaths=json.loads(result_pennsylvania_state_deaths)

# PUERTO RICO STATE DATA:
queries_puerto_rico_state_cases= pd.read_sql(f"select * from states_cases where state = 'Puerto Rico' and NOT state ISNULL and cases != 'N'",conn)
result_puerto_rico_state_cases=queries_puerto_rico_state_cases.to_json(orient='index')
parsed_puerto_rico_state_cases=json.loads(result_puerto_rico_state_cases)

queries_puerto_rico_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Puerto Rico' and NOT state ISNULL and deaths != 'N'",conn)
result_puerto_rico_state_deaths=queries_puerto_rico_state_deaths.to_json(orient='index')
parsed_puerto_rico_state_deaths=json.loads(result_puerto_rico_state_deaths)

# RHODE ISLAND STATE DATA:
queries_rhode_island_state_cases= pd.read_sql(f"select * from states_cases where state = 'Rhode Island' and NOT state ISNULL and cases != 'N'",conn)
result_rhode_island_state_cases=queries_rhode_island_state_cases.to_json(orient='index')
parsed_rhode_island_state_cases=json.loads(result_rhode_island_state_cases)

queries_rhode_island_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Rhode Island' and NOT state ISNULL and deaths != 'N'",conn)
result_rhode_island_state_deaths=queries_rhode_island_state_deaths.to_json(orient='index')
parsed_rhode_island_state_deaths=json.loads(result_rhode_island_state_deaths)

# SOUTH CAROLINA STATE DATA:
queries_south_carolina_state_cases= pd.read_sql(f"select * from states_cases where state = 'South Carolina' and NOT state ISNULL and cases != 'N'",conn)
result_south_carolina_state_cases=queries_south_carolina_state_cases.to_json(orient='index')
parsed_south_carolina_state_cases=json.loads(result_south_carolina_state_cases)

queries_south_carolina_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'South Carolina' and NOT state ISNULL and deaths != 'N'",conn)
result_south_carolina_state_deaths=queries_south_carolina_state_deaths.to_json(orient='index')
parsed_south_carolina_state_deaths=json.loads(result_south_carolina_state_deaths)

# SOUTH DAKOTA STATE DATA:
queries_south_dakota_state_cases= pd.read_sql(f"select * from states_cases where state = 'South Dakota' and NOT state ISNULL and cases != 'N'",conn)
result_south_dakota_state_cases=queries_south_dakota_state_cases.to_json(orient='index')
parsed_south_dakota_state_cases=json.loads(result_south_dakota_state_cases)

queries_south_dakota_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'South Dakota' and NOT state ISNULL and deaths != 'N'",conn)
result_south_dakota_state_deaths=queries_south_dakota_state_deaths.to_json(orient='index')
parsed_south_dakota_state_deaths=json.loads(result_south_dakota_state_deaths)

# TENNESSEE STATE DATA:
queries_tennessee_state_cases= pd.read_sql(f"select * from states_cases where state = 'Tennessee' and NOT state ISNULL and cases != 'N'",conn)
result_tennessee_state_cases=queries_tennessee_state_cases.to_json(orient='index')
parsed_tennessee_state_cases=json.loads(result_tennessee_state_cases)

queries_tennessee_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Tennessee' and NOT state ISNULL and deaths != 'N'",conn)
result_tennessee_state_deaths=queries_tennessee_state_deaths.to_json(orient='index')
parsed_tennessee_state_deaths=json.loads(result_tennessee_state_deaths)

# TEXAS STATE DATA:
queries_texas_state_cases= pd.read_sql(f"select * from states_cases where state = 'Texas' and NOT state ISNULL and cases != 'N'",conn)
result_texas_state_cases=queries_texas_state_cases.to_json(orient='index')
parsed_texas_state_cases=json.loads(result_texas_state_cases)

queries_texas_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Texas' and NOT state ISNULL and deaths != 'N'",conn)
result_texas_state_deaths=queries_texas_state_deaths.to_json(orient='index')
parsed_texas_state_deaths=json.loads(result_texas_state_deaths)

# UTAH STATE DATA:
queries_utah_state_cases= pd.read_sql(f"select * from states_cases where state = 'Utah' and NOT state ISNULL and cases != 'N'",conn)
result_utah_state_cases=queries_utah_state_cases.to_json(orient='index')
parsed_utah_state_cases=json.loads(result_utah_state_cases)

queries_utah_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Utah' and NOT state ISNULL and deaths != 'N'",conn)
result_utah_state_deaths=queries_utah_state_deaths.to_json(orient='index')
parsed_utah_state_deaths=json.loads(result_utah_state_deaths)

# VERMONT STATE DATA:
queries_vermont_state_cases= pd.read_sql(f"select * from states_cases where state = 'Vermont' and NOT state ISNULL and cases != 'N'",conn)
result_vermont_state_cases=queries_vermont_state_cases.to_json(orient='index')
parsed_vermont_state_cases=json.loads(result_vermont_state_cases)

queries_vermont_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Vermont' and NOT state ISNULL and deaths != 'N'",conn)
result_vermont_state_deaths=queries_vermont_state_deaths.to_json(orient='index')
parsed_vermont_state_deaths=json.loads(result_vermont_state_deaths)

# VIRGIN ISLANDS STATE DATA:
queries_virgin_islands_state_cases= pd.read_sql(f"select * from states_cases where state = 'Virgin Islands' and NOT state ISNULL and cases != 'N'",conn)
result_virgin_islands_state_cases=queries_virgin_islands_state_cases.to_json(orient='index')
parsed_virgin_islands_state_cases=json.loads(result_virgin_islands_state_cases)

queries_virgin_islands_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Virgin Islands' and NOT state ISNULL and deaths != 'N'",conn)
result_virgin_islands_state_deaths=queries_virgin_islands_state_deaths.to_json(orient='index')
parsed_virgin_islands_state_deaths=json.loads(result_virgin_islands_state_deaths)

# VIRGINIA STATE DATA:
queries_virginia_state_cases= pd.read_sql(f"select * from states_cases where state = 'Virginia' and NOT state ISNULL and cases != 'N'",conn)
result_virginia_state_cases=queries_virginia_state_cases.to_json(orient='index')
parsed_virginia_state_cases=json.loads(result_virginia_state_cases)

queries_virginia_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Virginia' and NOT state ISNULL and deaths != 'N'",conn)
result_virginia_state_deaths=queries_virginia_state_deaths.to_json(orient='index')
parsed_virginia_state_deaths=json.loads(result_virginia_state_deaths)

# WASHINGTON STATE DATA:
queries_washington_state_cases= pd.read_sql(f"select * from states_cases where state = 'Washington' and NOT state ISNULL and cases != 'N'",conn)
result_washington_state_cases=queries_washington_state_cases.to_json(orient='index')
parsed_washington_state_cases=json.loads(result_washington_state_cases)

queries_washington_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Washington' and NOT state ISNULL and deaths != 'N'",conn)
result_washington_state_deaths=queries_washington_state_deaths.to_json(orient='index')
parsed_washington_state_deaths=json.loads(result_washington_state_deaths)

# WEST VIRGINIA STATE DATA:
queries_west_virginia_state_cases= pd.read_sql(f"select * from states_cases where state = 'West Virginia' and NOT state ISNULL and cases != 'N'",conn)
result_west_virginia_state_cases=queries_west_virginia_state_cases.to_json(orient='index')
parsed_west_virginia_state_cases=json.loads(result_west_virginia_state_cases)

queries_west_virginia_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'West Virginia' and NOT state ISNULL and deaths != 'N'",conn)
result_west_virginia_state_deaths=queries_west_virginia_state_deaths.to_json(orient='index')
parsed_west_virginia_state_deaths=json.loads(result_west_virginia_state_deaths)

# WISCONSIN STATE DATA:
queries_wisconsin_state_cases= pd.read_sql(f"select * from states_cases where state = 'Wisconsin' and NOT state ISNULL and cases != 'N'",conn)
result_wisconsin_state_cases=queries_wisconsin_state_cases.to_json(orient='index')
parsed_wisconsin_state_cases=json.loads(result_wisconsin_state_cases)

queries_wisconsin_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Wisconsin' and NOT state ISNULL and deaths != 'N'",conn)
result_wisconsin_state_deaths=queries_wisconsin_state_deaths.to_json(orient='index')
parsed_wisconsin_state_deaths=json.loads(result_wisconsin_state_deaths)

# WYOMING STATE DATA:
queries_wyoming_state_cases= pd.read_sql(f"select * from states_cases where state = 'Wyoming' and NOT state ISNULL and cases != 'N'",conn)
result_wyoming_state_cases=queries_wyoming_state_cases.to_json(orient='index')
parsed_wyoming_state_cases=json.loads(result_wyoming_state_cases)

queries_wyoming_state_deaths= pd.read_sql(f"select * from states_deaths where state = 'Wyoming' and NOT state ISNULL and deaths != 'N'",conn)
result_wyoming_state_deaths=queries_wyoming_state_deaths.to_json(orient='index')
parsed_wyoming_state_deaths=json.loads(result_wyoming_state_deaths)

# %%
states_list_df = pd.read_sql("select distinct state from states_cases WHERE NOT state = 'None'",conn).sort_values('state')
states_list= states_list_df['state']
states_list
# Out:
# 5                      Alabama
# 4                       Alaska
# 41                     Arizona
# 24                    Arkansas
# 53                  California
# 8                     Colorado
# 26                 Connecticut
# 13                    Delaware
# 28        District of Columbia
# 10                     Florida
# 46                     Georgia
# 18                        Guam
# 23                      Hawaii
# 3                        Idaho
# 42                    Illinois
# 30                     Indiana
# 29                        Iowa
# 0                       Kansas
# 40                    Kentucky
# 16                   Louisiana
# 52                       Maine
# 44                    Maryland
# 31               Massachusetts
# 34                    Michigan
# 35                   Minnesota
# 9                  Mississippi
# 25                    Missouri
# 39                     Montana
# 51                    Nebraska
# 15                      Nevada
# 49               New Hampshire
# 21                  New Jersey
# 22                  New Mexico
# 17                    New York
# 7               North Carolina
# 50                North Dakota
# 14    Northern Mariana Islands
# 33                        Ohio
# 6                     Oklahoma
# 2                       Oregon
# 36                Pennsylvania
# 45                 Puerto Rico
# 32                Rhode Island
# 20              South Carolina
# 27                South Dakota
# 54                   Tennessee
# 1                        Texas
# 47                        Utah
# 12                     Vermont
# 11              Virgin Islands
# 43                    Virginia
# 37                  Washington
# 19               West Virginia
# 38                   Wisconsin
# 48                     Wyoming
# Name: state, dtype: object

# %%
# run cases_best_training_model on EVERY state to get a dictionary of models

case_results = []
case_forecasts = []
sarimax_case_rmse = []
case_models={}
case_splits={}
case_full_models={}

# loop through counties
i = 0 
while i < len(states_list):
    state=states_list[i]
    print(state)
    
    #get data for state     
    df= pd.read_sql(f"select * from states_cases where state = '{state}' and NOT 'date' ISNULL and cases != 'N'",conn)
    
    #     manipulate data as needed to run ML
    df['cases']  = pd.to_numeric(df['cases']).astype(np.int64)
    ML_Data=df[['date', 'cases']]
    ML_Data=ML_Data.dropna(how='any', axis=0)
    ML_Data=ML_Data.set_index('date')
    ML_Data=ML_Data.fillna(0)
    ML_Data.head()
  
    print(f' Currently processing {state}, number {i+1} of {len(states_list)} states')
    
    #  test train split
    end_train=today- timedelta(days=30)
    start_test=today- timedelta(days=29)
    train=ML_Data[:end_train]
    test=ML_Data[start_test:]
    case_splits.update({'state':states_list[i]})
    case_splits.update({'train':train})
    case_splits.update({'test':test})
    #     print(splits['test'].index)
    
    #   call fxn to determine model best params & run model with them
    #   cases_best_training_model(countyData)
    stepwise_fit = auto_arima(train, start_p = 1, start_q = 1, 
                          max_p = 10, max_q = 30, m = 2,
                          start_P = 0, seasonal = True, 
                          stationary=True,
                          trace = True, 
                          error_action ='ignore',   # we don't want to know if an order does not work 
                          suppress_warnings = True,  # we don't want convergence warnings 
                          stepwise = True)           # set to stepwise 
  
    # pull out the parameters of the best model for this county
    x=stepwise_fit.get_params()
    
    # override Q parameter if 0 to 1
    so=x['seasonal_order']
    so_slice1=so[ :2]
    if so[2]==0:
        so=so_slice1+ (1, 2)
        
     # runs model with best fit ARIMA params
    model = SARIMAX(train,
                    order = (x['order']),
                    seasonal_order =(so),
                    initialization='approximate_diffuse')

    result = model.fit()
    case_models.update({state: result})
    
    start = len(train) 
    end = len(train) + len(test) - 1

    # Predictions for the test set 
    predictions = result.predict(start, end)
    predicted_df = pd.DataFrame(data=predictions, columns=["sarimax_cases_predicted"])
    predicted_df['sarimax_cases_expected'] = test
    modeled_df = predicted_df.drop(columns='sarimax_cases_expected')
    
    #     # Calculate rmse and store
    #     rmse = sqrt(mean_squared_error(predicted_df['sarimax_cases_expected'], predicted_df['sarimax_cases_predicted']))
    #     sarimax_case_rmse.append(rmse)
    
    # Calculate residuals
    residuals = predicted_df['sarimax_cases_expected'] - predicted_df['sarimax_cases_predicted']
    residuals_df = pd.DataFrame(data=residuals, columns=["sarimax_cases_residuals"])
    
    # Put everything together in dataframe  
    results_df = modeled_df.join(residuals_df)
    results_df['state']=state
    case_results.append(results_df)
    
    #  get results for full dataset:
    end_full=today- timedelta(days=5)
    start_full=today- timedelta(days=230)
    formodel=ML_Data[start_full:end_full]

    #   cases_best_training_model for full data
    stepwise_fit_full = auto_arima(formodel, start_p = 1, start_q = 1, 
                                   max_p = 10, max_q = 30, m = 2,
                                   start_P = 0, seasonal = True, 
                                   stationary=True,
                                   trace = True, 
                                   error_action ='ignore',   # we don't want to know if an order does not work 
                                   suppress_warnings = True,  # we don't want convergence warnings 
                                   stepwise = True)           # set to stepwise 
    
    # pull out the parameters of the best model for this county
    x_full=stepwise_fit_full.get_params()
    
    # override Q parameter if 0 to 1
    so_full=x_full['seasonal_order']
    so_full_slice1=so_full[ :2]
    if so_full[2]==0:
        so_full=so_full_slice1+ (1, 2)
    
    # runs model with best fit ARIMA params
    full_model = SARIMAX(formodel,
                    order = (x_full['order']),
                    seasonal_order =(so_full),
                    initialization='approximate_diffuse')

    full_result = full_model.fit()
    case_full_models.update({state: full_result})
    
    # Getting 90 days for forecasts and store
    SARIMAX_forecast = round(full_result.forecast(steps = 90))
    endforecast=tomorrow + timedelta(days=90)
    idx = pd.date_range(tomorrow, endforecast, freq='d')
    SARIMAX_forecast = pd.DataFrame(list(zip(list(idx),list(SARIMAX_forecast))),
                                    columns=['date','sarimax_cases_forecasted'])
    SARIMAX_forecast['state']=state
    case_forecasts.append(SARIMAX_forecast)
    
    i = i + 1
    print("Done")
# Out:
# Kansas
#  Currently processing Kansas, number 1 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4578.173, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6751.192, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6917.869, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4654.090, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=4396.197, Time=0.34 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=4405.977, Time=0.32 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=4387.288, Time=0.41 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=4389.250, Time=0.34 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=4390.888, Time=0.44 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=4391.652, Time=0.41 sec
#  ARIMA(0,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=4471.725, Time=0.42 sec
#  ARIMA(0,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=nan sec
#
# Best model:  ARIMA(1,0,1)(2,0,1)[2] intercept
# Total fit time: 4.957 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3894.132, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5430.526, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5612.271, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3946.502, Time=0.20 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3763.017, Time=0.33 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3773.192, Time=0.26 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3764.583, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3797.512, Time=0.40 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3762.423, Time=0.34 sec
#  ARIMA(0,0,1)(2,0,0)[2] intercept   : AIC=5245.971, Time=0.12 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(2,0,0)[2] intercept   : AIC=5335.728, Time=0.13 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3759.924, Time=0.19 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3771.533, Time=0.12 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3761.973, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3760.802, Time=0.19 sec
#  ARIMA(0,0,1)(2,0,0)[2]             : AIC=inf, Time=0.56 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(2,0,0)[2]             : AIC=inf, Time=0.15 sec
#
# Best model:  ARIMA(1,0,1)(2,0,0)[2]
# Total fit time: 5.074 seconds
# Done
# Texas
#  Currently processing Texas, number 2 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=5413.119, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=8228.752, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=7966.381, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=8395.723, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=5592.167, Time=0.30 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=5251.869, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=5253.001, Time=0.43 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=5254.565, Time=0.72 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=5358.155, Time=0.54 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=5243.855, Time=0.52 sec
#  ARIMA(0,0,1)(2,0,0)[2] intercept   : AIC=7979.627, Time=0.21 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,0)(2,0,0)[2] intercept   : AIC=8072.564, Time=0.15 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=5221.844, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=5233.681, Time=0.38 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=0.48 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=5256.050, Time=0.47 sec
#  ARIMA(0,0,1)(2,0,0)[2]             : AIC=8117.932, Time=0.12 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.42 sec
#  ARIMA(0,0,0)(2,0,0)[2]             : AIC=inf, Time=0.18 sec
#
# Best model:  ARIMA(1,0,1)(2,0,0)[2]
# Total fit time: 7.648 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4346.651, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6451.709, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=4346.138, Time=0.20 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=6244.796, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6679.847, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=4313.360, Time=0.28 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=4350.012, Time=0.25 sec
#  ARIMA(0,0,0)(2,0,0)[2] intercept   : AIC=6374.896, Time=0.09 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=4214.019, Time=0.31 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=4221.291, Time=0.23 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=4221.239, Time=0.31 sec
#  ARIMA(0,0,1)(2,0,0)[2] intercept   : AIC=6268.205, Time=0.11 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=4203.118, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=0.34 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=4163.623, Time=0.28 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4322.400, Time=0.16 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=4193.325, Time=0.31 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=4464.659, Time=0.14 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=4288.825, Time=0.25 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=4203.178, Time=0.33 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=6466.866, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=4196.337, Time=0.23 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=4760.312, Time=0.18 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 5.826 seconds
# Done
# Oregon
#  Currently processing Oregon, number 3 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3490.821, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6402.883, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6580.334, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3728.906, Time=0.23 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3265.072, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3281.688, Time=0.38 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3403.629, Time=0.32 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3270.131, Time=0.38 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3250.285, Time=0.31 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=3732.238, Time=0.24 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=3258.378, Time=0.44 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3615.003, Time=0.34 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3250.283, Time=0.29 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=3730.936, Time=0.15 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=inf, Time=0.34 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(0,0,0)[2]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3607.382, Time=0.18 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=4098.686, Time=0.16 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=nan sec
#
# Best model:  ARIMA(1,0,0)(1,0,1)[2]
# Total fit time: 9.368 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3012.542, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5096.550, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5309.541, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3203.737, Time=0.13 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=2921.993, Time=0.30 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3088.107, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=2920.467, Time=0.32 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3011.292, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,2)[2]             : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3085.529, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,2)[2]             : AIC=inf, Time=0.15 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2]
# Total fit time: 5.247 seconds
# Done
# Idaho
#  Currently processing Idaho, number 4 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3946.140, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6584.084, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6729.583, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4095.533, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3730.797, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3787.134, Time=0.29 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3725.180, Time=0.46 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3750.081, Time=0.40 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3777.704, Time=0.39 sec
#  ARIMA(0,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=3752.138, Time=0.39 sec
#  ARIMA(0,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3722.638, Time=0.27 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3725.723, Time=0.27 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3745.521, Time=0.21 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3786.009, Time=0.16 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,1)(2,0,1)[2]             : AIC=inf, Time=0.28 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=3745.634, Time=0.26 sec
#  ARIMA(0,0,0)(2,0,1)[2]             : AIC=inf, Time=0.44 sec
#
# Best model:  ARIMA(1,0,1)(2,0,1)[2]
# Total fit time: 7.025 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3325.560, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5274.054, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5446.444, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3418.263, Time=0.23 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3145.841, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3130.891, Time=0.60 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3168.010, Time=0.38 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3125.619, Time=0.48 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3257.665, Time=0.39 sec
#  ARIMA(0,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=3123.579, Time=0.35 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3367.294, Time=0.32 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3145.019, Time=0.30 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=3141.598, Time=0.54 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=3445.230, Time=0.27 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=3133.067, Time=0.43 sec
#  ARIMA(0,0,0)(1,0,2)[2] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=3119.347, Time=0.32 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3369.721, Time=0.25 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3143.719, Time=0.21 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=3123.459, Time=0.42 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=3443.904, Time=0.13 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=3128.777, Time=0.25 sec
#  ARIMA(0,0,0)(1,0,2)[2]             : AIC=inf, Time=0.28 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3198.167, Time=0.23 sec
#  ARIMA(0,0,1)(1,0,2)[2]             : AIC=inf, Time=0.73 sec
#
# Best model:  ARIMA(1,0,0)(1,0,2)[2]
# Total fit time: 10.004 seconds
# Done
# Alaska
#  Currently processing Alaska, number 5 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3086.280, Time=0.43 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5720.417, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5845.292, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3343.162, Time=0.23 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=2821.028, Time=0.49 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=2844.140, Time=0.33 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=2832.891, Time=0.59 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=2821.220, Time=0.57 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3036.220, Time=0.48 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=2835.551, Time=0.50 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=2798.184, Time=0.68 sec
#  ARIMA(0,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=2888.954, Time=0.56 sec
#  ARIMA(0,0,0)(2,0,2)[2] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=2796.810, Time=0.59 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=2819.832, Time=0.39 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=2831.806, Time=0.43 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=2819.776, Time=0.25 sec
#  ARIMA(0,0,1)(2,0,2)[2]             : AIC=inf, Time=0.39 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=2891.034, Time=0.42 sec
#  ARIMA(0,0,0)(2,0,2)[2]             : AIC=inf, Time=nan sec
#
# Best model:  ARIMA(1,0,1)(2,0,2)[2]
# Total fit time: 9.277 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2691.305, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=4713.562, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=4840.023, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2886.610, Time=0.17 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=2585.648, Time=0.33 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=2768.887, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=2584.364, Time=0.30 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=2690.027, Time=0.20 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=2376.368, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=inf, Time=0.52 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=2376.808, Time=0.30 sec
#  ARIMA(0,0,1)(1,0,2)[2]             : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=2471.762, Time=0.21 sec
#  ARIMA(0,0,0)(1,0,2)[2]             : AIC=3040.310, Time=0.24 sec
#
# Best model:  ARIMA(1,0,1)(1,0,2)[2]
# Total fit time: 6.051 seconds
# Done
# Alabama
#  Currently processing Alabama, number 6 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4475.808, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=7282.353, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=7456.316, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4625.819, Time=0.28 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=4300.716, Time=0.43 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=4306.296, Time=0.49 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=4317.295, Time=0.74 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=4406.901, Time=0.44 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=4311.738, Time=0.43 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=7009.998, Time=0.22 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=4336.312, Time=0.59 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=4232.328, Time=0.57 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4454.463, Time=0.39 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=4302.736, Time=0.54 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=4233.436, Time=0.35 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=4622.189, Time=0.26 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=4407.278, Time=0.37 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=4295.173, Time=0.41 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.30 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=4266.661, Time=0.19 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=4980.563, Time=0.23 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 11.380 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3604.662, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5712.444, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=3527.206, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5949.689, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=3565.030, Time=0.36 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3594.759, Time=0.30 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=3737.791, Time=0.28 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(1,0,0)[2] intercept   : AIC=5638.995, Time=0.02 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3459.363, Time=0.27 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3752.037, Time=0.24 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3457.464, Time=0.35 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3453.583, Time=0.30 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3424.685, Time=0.42 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3561.587, Time=0.34 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,1)(1,0,2)[2] intercept   : AIC=5493.618, Time=0.12 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=3593.936, Time=0.31 sec
#  ARIMA(0,0,0)(1,0,2)[2] intercept   : AIC=5515.135, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3415.893, Time=0.45 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3545.673, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3413.501, Time=0.32 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3584.661, Time=0.26 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=3725.632, Time=0.08 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=inf, Time=0.34 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=3436.857, Time=0.36 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=5736.670, Time=0.11 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3438.029, Time=0.25 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=4007.324, Time=0.24 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 8.928 seconds
# Done
# Oklahoma
#  Currently processing Oklahoma, number 7 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4177.196, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6971.017, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=7114.082, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4347.872, Time=0.31 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3881.636, Time=0.44 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3942.245, Time=0.26 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3929.148, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3913.797, Time=0.43 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=4079.034, Time=0.33 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3915.928, Time=0.38 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3964.249, Time=0.35 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3879.635, Time=0.25 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4168.219, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3941.443, Time=0.18 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3881.584, Time=0.40 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3881.590, Time=0.36 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=4347.177, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=4072.850, Time=0.30 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3914.730, Time=0.26 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=3885.325, Time=0.55 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.59 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=inf, Time=nan sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=4747.975, Time=0.37 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 8.670 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3654.881, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5565.527, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5738.719, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3747.760, Time=0.21 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3519.693, Time=0.41 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3596.878, Time=0.32 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3515.289, Time=0.44 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3542.523, Time=0.33 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3511.680, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3632.181, Time=0.30 sec
#  ARIMA(0,0,1)(1,0,2)[2] intercept   : AIC=5356.211, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=3510.536, Time=0.37 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3698.556, Time=0.38 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3517.378, Time=0.29 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=3517.557, Time=0.41 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=3749.965, Time=0.21 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=3512.445, Time=0.37 sec
#  ARIMA(0,0,0)(1,0,2)[2] intercept   : AIC=5366.507, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=3507.063, Time=0.29 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3703.788, Time=0.24 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3514.820, Time=0.13 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=3518.380, Time=0.38 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=3752.609, Time=0.10 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=3509.242, Time=0.23 sec
#  ARIMA(0,0,0)(1,0,2)[2]             : AIC=4061.712, Time=0.27 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3509.543, Time=0.24 sec
#  ARIMA(0,0,1)(1,0,2)[2]             : AIC=inf, Time=0.43 sec
#
# Best model:  ARIMA(1,0,0)(1,0,2)[2]
# Total fit time: 8.030 seconds
# Done
# North Carolina
#  Currently processing North Carolina, number 8 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4589.302, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=7468.996, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=7649.162, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4781.249, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=4514.330, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=4702.223, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=4500.299, Time=0.25 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4567.543, Time=0.17 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=4333.667, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=4378.971, Time=0.38 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,1)(1,0,2)[2]             : AIC=7373.346, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(0,0,0)(1,0,2)[2]             : AIC=5017.485, Time=0.40 sec
#
# Best model:  ARIMA(1,0,1)(1,0,2)[2]
# Total fit time: 5.836 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3794.537, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5864.501, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=3714.677, Time=0.23 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=5643.427, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6105.909, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=3705.084, Time=0.31 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3726.018, Time=0.26 sec
#  ARIMA(0,0,0)(2,0,0)[2] intercept   : AIC=5791.892, Time=0.09 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3700.797, Time=0.33 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3707.352, Time=0.26 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3729.407, Time=0.33 sec
#  ARIMA(0,0,1)(2,0,0)[2] intercept   : AIC=5672.364, Time=0.12 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3639.678, Time=0.26 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3663.751, Time=0.15 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3601.374, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3589.172, Time=0.42 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3778.956, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3592.552, Time=0.37 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=3924.957, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3730.382, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=3603.008, Time=0.43 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=5892.958, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3587.272, Time=0.24 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=3877.991, Time=0.16 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=3592.954, Time=0.31 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=3589.371, Time=0.35 sec
#  ARIMA(1,0,0)(0,0,0)[2]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3815.096, Time=0.24 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.19 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=3592.432, Time=0.31 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=4231.723, Time=0.32 sec
#
# Best model:  ARIMA(1,0,0)(1,0,1)[2]
# Total fit time: 8.420 seconds
# Done
# Colorado
#  Currently processing Colorado, number 9 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4076.305, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6842.335, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=7075.580, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4327.466, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3981.036, Time=0.34 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=4239.943, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3977.726, Time=0.32 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4075.008, Time=0.18 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,2)[2]             : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=4238.218, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,2)[2]             : AIC=inf, Time=0.18 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2]
# Total fit time: 5.383 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3592.071, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5537.160, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5752.434, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3771.233, Time=0.21 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3461.563, Time=0.34 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3470.073, Time=0.34 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2] intercept
# Total fit time: 2.996 seconds
# Done
# Mississippi
#  Currently processing Mississippi, number 10 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4209.530, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=7014.665, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=7200.650, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4332.847, Time=0.26 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=4075.128, Time=0.40 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=4065.028, Time=0.34 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=4072.339, Time=0.40 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=4075.436, Time=0.44 sec
#  ARIMA(0,0,1)(1,0,0)[2] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(1,0,0)[2] intercept   : AIC=6867.394, Time=0.04 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=inf, Time=0.28 sec
#
# Best model:  ARIMA(1,0,1)(1,0,0)[2] intercept
# Total fit time: 3.120 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3383.269, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5485.963, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5743.731, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3490.083, Time=0.21 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3285.843, Time=0.33 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3270.629, Time=0.26 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3274.179, Time=0.34 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3280.737, Time=0.37 sec
#  ARIMA(0,0,1)(1,0,0)[2] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(1,0,0)[2] intercept   : AIC=5419.164, Time=0.03 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=inf, Time=0.27 sec
#
# Best model:  ARIMA(1,0,1)(1,0,0)[2] intercept
# Total fit time: 2.698 seconds
# Done
# Florida
#  Currently processing Florida, number 11 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=5278.245, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=8172.948, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=5095.247, Time=0.27 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=7911.875, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=8347.752, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=5047.641, Time=0.44 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=5172.453, Time=0.32 sec
#  ARIMA(0,0,0)(2,0,0)[2] intercept   : AIC=8020.888, Time=0.11 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(0,0,1)(2,0,0)[2] intercept   : AIC=7925.779, Time=0.11 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.26 sec
#
# Best model:  ARIMA(1,0,0)(2,0,0)[2] intercept
# Total fit time: 2.967 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4282.032, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6372.781, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=6165.743, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6622.095, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4444.309, Time=0.20 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=4149.864, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=4153.700, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=4206.638, Time=0.35 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=4155.610, Time=0.37 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=6162.925, Time=0.08 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=4200.951, Time=0.26 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=6197.864, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=4186.140, Time=0.36 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2] intercept
# Total fit time: 4.374 seconds
# Done
# Virgin Islands
#  Currently processing Virgin Islands, number 12 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2191.182, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=4482.345, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=4625.814, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2252.947, Time=0.21 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=2111.555, Time=0.40 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=2157.423, Time=0.29 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=2113.334, Time=0.54 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=2113.125, Time=0.68 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=2166.651, Time=0.44 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=2145.565, Time=0.39 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=2115.353, Time=0.49 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=2110.365, Time=0.28 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=2212.517, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=2112.116, Time=0.61 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=2111.992, Time=0.44 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=2177.870, Time=0.32 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=2114.138, Time=0.53 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=2109.289, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=2211.227, Time=0.12 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=2111.039, Time=0.28 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=2110.916, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,0)[2]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=2176.592, Time=0.18 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.22 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=2113.062, Time=0.38 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=2491.629, Time=0.22 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=2110.484, Time=0.22 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.68 sec
#
# Best model:  ARIMA(1,0,0)(1,0,1)[2]
# Total fit time: 10.549 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=1775.145, Time=0.30 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=3521.733, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=3726.172, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=1819.246, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=1711.905, Time=0.43 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=1749.310, Time=0.33 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=1713.979, Time=0.47 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=1713.850, Time=0.47 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=1755.835, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=1737.846, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=1715.786, Time=0.38 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=1710.558, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=1791.481, Time=0.17 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=1712.548, Time=0.36 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=1712.544, Time=0.31 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=1764.497, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=1709.584, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=1790.269, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=1711.574, Time=0.21 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=1711.570, Time=0.20 sec
#  ARIMA(1,0,0)(0,0,0)[2]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=1763.301, Time=0.17 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=1713.583, Time=0.29 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=2009.244, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=1710.939, Time=0.20 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.16 sec
#
# Best model:  ARIMA(1,0,0)(1,0,1)[2]
# Total fit time: 8.230 seconds
# Done
# Vermont
#  Currently processing Vermont, number 13 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2062.041, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=4626.317, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=4968.292, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2179.746, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=1979.950, Time=0.73 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=2011.822, Time=0.44 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=2010.796, Time=0.64 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=1980.027, Time=0.61 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=2041.035, Time=0.42 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=1999.358, Time=0.46 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=1976.248, Time=0.69 sec
#  ARIMA(0,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=2003.759, Time=0.61 sec
#  ARIMA(0,0,0)(2,0,2)[2] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=1975.237, Time=0.46 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=1978.842, Time=0.37 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=2010.345, Time=0.28 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=1978.831, Time=0.31 sec
#  ARIMA(0,0,1)(2,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=2002.650, Time=0.38 sec
#  ARIMA(0,0,0)(2,0,2)[2]             : AIC=2510.090, Time=0.82 sec
#
# Best model:  ARIMA(1,0,1)(2,0,2)[2]
# Total fit time: 9.760 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2036.736, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=3619.713, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=4024.720, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2120.167, Time=0.22 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=1978.366, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=2000.902, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=1977.527, Time=0.25 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=2035.919, Time=0.15 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=1931.202, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=1927.963, Time=0.21 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=1965.854, Time=0.16 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=1930.047, Time=0.31 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=2119.348, Time=0.09 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=1939.607, Time=0.24 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=1931.079, Time=0.46 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.29 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=1926.751, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=2095.379, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=1928.708, Time=0.25 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=1928.691, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,0)[2]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=2000.086, Time=0.18 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.17 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=1929.396, Time=0.33 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=2339.560, Time=0.12 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=1927.654, Time=0.42 sec
#
# Best model:  ARIMA(1,0,0)(1,0,1)[2]
# Total fit time: 7.817 seconds
# Done
# Delaware
#  Currently processing Delaware, number 14 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3396.644, Time=0.40 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6078.746, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6345.080, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3489.979, Time=0.29 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3266.244, Time=0.48 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3341.278, Time=0.36 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3349.129, Time=0.59 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3365.647, Time=0.44 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3291.028, Time=0.49 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3242.134, Time=0.40 sec
#  ARIMA(1,0,0)(0,0,1)[2] intercept   : AIC=3499.724, Time=0.27 sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=3244.338, Time=0.46 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=3267.596, Time=0.51 sec
#  ARIMA(1,0,0)(0,0,0)[2] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3434.598, Time=0.45 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,0)(2,0,2)[2] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3236.282, Time=0.22 sec
#  ARIMA(1,0,0)(0,0,1)[2]             : AIC=3498.422, Time=0.12 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=3242.350, Time=0.26 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=3243.148, Time=0.47 sec
#  ARIMA(1,0,0)(0,0,0)[2]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3429.664, Time=0.17 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.19 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=3239.659, Time=0.41 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=3823.916, Time=0.14 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3236.233, Time=0.28 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3394.035, Time=0.19 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3340.828, Time=0.35 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3343.719, Time=0.44 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3245.291, Time=0.46 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=3488.679, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3359.670, Time=0.22 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3287.769, Time=0.29 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=3238.406, Time=0.53 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.37 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 14.349 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2789.576, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=4686.281, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5073.301, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2897.603, Time=0.17 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=2647.804, Time=0.37 sec
# ...
# Done
# North Dakota
#  Currently processing North Dakota, number 51 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3697.756, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6272.951, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6386.636, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3946.532, Time=0.22 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3579.515, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3823.869, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3577.932, Time=0.20 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3696.465, Time=0.17 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,1)(0,0,2)[2]             : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3822.126, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,2)[2]             : AIC=inf, Time=0.16 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2]
# Total fit time: 4.966 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3126.972, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5150.097, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5268.354, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3315.716, Time=0.18 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3024.429, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=3177.357, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3022.859, Time=0.33 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3125.690, Time=0.19 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,1)(0,0,2)[2]             : AIC=inf, Time=0.26 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=3175.270, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,2)[2]             : AIC=inf, Time=0.18 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2]
# Total fit time: 4.869 seconds
# Done
# Nebraska
#  Currently processing Nebraska, number 52 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4002.286, Time=0.30 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6602.843, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6801.580, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4182.320, Time=0.26 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3841.678, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3855.004, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3856.946, Time=0.57 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3832.663, Time=0.70 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3933.807, Time=0.47 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=3847.245, Time=0.69 sec
#  ARIMA(0,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=3890.449, Time=0.44 sec
#  ARIMA(0,0,0)(1,0,2)[2] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3837.501, Time=0.44 sec
#
# Best model:  ARIMA(1,0,1)(1,0,2)[2] intercept
# Total fit time: 6.341 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3409.617, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5312.061, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5521.412, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3550.120, Time=0.31 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3291.591, Time=0.44 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3316.706, Time=0.32 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3320.234, Time=0.48 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=3310.132, Time=0.48 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3396.367, Time=0.45 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3317.216, Time=0.43 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3296.474, Time=0.35 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3273.677, Time=0.34 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3408.121, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3315.258, Time=0.22 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3318.205, Time=0.35 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=3275.741, Time=0.38 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=3548.842, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=3390.635, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3310.282, Time=0.27 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=3268.285, Time=0.66 sec
#  ARIMA(0,0,1)(2,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=3291.884, Time=0.52 sec
#  ARIMA(0,0,0)(2,0,2)[2]             : AIC=inf, Time=0.52 sec
#
# Best model:  ARIMA(1,0,1)(2,0,2)[2]
# Total fit time: 9.749 seconds
# Done
# Maine
#  Currently processing Maine, number 53 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2520.740, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5296.318, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=5565.267, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2705.223, Time=0.24 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=2365.349, Time=0.48 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=2367.124, Time=0.30 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=2370.426, Time=0.56 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=2361.416, Time=0.56 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=2465.463, Time=0.45 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=2368.968, Time=0.63 sec
#  ARIMA(0,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(1,0,0)(1,0,2)[2] intercept   : AIC=2443.053, Time=0.62 sec
#  ARIMA(0,0,0)(1,0,2)[2] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=2359.236, Time=0.44 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=2464.169, Time=0.23 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=2364.180, Time=0.41 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=2358.740, Time=0.52 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=2362.061, Time=0.46 sec
#  ARIMA(0,0,1)(2,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=2438.094, Time=0.45 sec
#  ARIMA(0,0,0)(2,0,2)[2]             : AIC=inf, Time=0.68 sec
#
# Best model:  ARIMA(1,0,1)(2,0,2)[2]
# Total fit time: 9.696 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=2315.019, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=4171.898, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=4500.479, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=2426.906, Time=0.23 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=2266.396, Time=0.40 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=2418.725, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=2265.269, Time=0.23 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=2313.887, Time=0.16 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=2195.967, Time=0.52 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=2172.485, Time=0.37 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=2203.100, Time=0.20 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=2425.768, Time=0.09 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=2187.864, Time=0.28 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=2174.615, Time=0.44 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=inf, Time=0.22 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=2216.816, Time=0.36 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=2744.365, Time=0.14 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 6.811 seconds
# Done
# California
#  Currently processing California, number 54 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=5229.346, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=8242.869, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=7981.047, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=8430.598, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=5472.479, Time=0.29 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=5070.352, Time=0.39 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=7970.300, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=5318.194, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=7988.518, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=5041.518, Time=0.38 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=5188.715, Time=0.31 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=0.68 sec
#  ARIMA(0,0,1)(0,0,2)[2]             : AIC=8162.862, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=5275.157, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,2)[2]             : AIC=8189.249, Time=0.06 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2]
# Total fit time: 5.354 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4254.870, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=6426.509, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=6221.371, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6691.443, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4443.474, Time=0.26 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=4134.316, Time=0.34 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,1)(0,0,2)[2] intercept   : AIC=6213.161, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,2)[2] intercept   : AIC=4319.798, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,2)[2] intercept   : AIC=6232.173, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=4115.587, Time=0.32 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4236.004, Time=0.32 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,2)[2]             : AIC=6486.756, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,2)[2]             : AIC=4288.654, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,2)[2]             : AIC=6509.880, Time=0.05 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[2]
# Total fit time: 4.084 seconds
# Done
# Tennessee
#  Currently processing Tennessee, number 55 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=4601.714, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=7422.586, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=7591.561, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=4790.535, Time=0.30 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=4442.769, Time=0.39 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=4432.286, Time=0.34 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=4412.102, Time=0.42 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(0,0,1)(2,0,0)[2] intercept   : AIC=7173.308, Time=0.11 sec
#  ARIMA(1,0,0)(2,0,0)[2] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(2,0,0)[2] intercept   : AIC=7267.556, Time=0.11 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=4387.686, Time=0.23 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=4416.725, Time=0.23 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=inf, Time=0.57 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=4342.088, Time=0.30 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=4587.166, Time=0.28 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=4358.675, Time=0.38 sec
#  ARIMA(1,0,1)(0,0,0)[2]             : AIC=4783.320, Time=0.13 sec
#  ARIMA(1,0,1)(0,0,2)[2]             : AIC=4509.150, Time=0.29 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=4346.339, Time=0.62 sec
#  ARIMA(0,0,1)(1,0,1)[2]             : AIC=7313.706, Time=0.08 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=4379.064, Time=0.79 sec
#  ARIMA(0,0,0)(1,0,1)[2]             : AIC=5137.639, Time=0.19 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[2]
# Total fit time: 7.613 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[2] intercept   : AIC=3826.375, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[2] intercept   : AIC=5857.820, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[2] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,0,1)(0,0,1)[2] intercept   : AIC=5651.915, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[2]             : AIC=6075.616, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[2] intercept   : AIC=3967.184, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,1)[2] intercept   : AIC=3694.748, Time=0.39 sec
#  ARIMA(1,0,1)(1,0,0)[2] intercept   : AIC=3711.473, Time=0.28 sec
#  ARIMA(1,0,1)(2,0,1)[2] intercept   : AIC=3694.960, Time=0.44 sec
#  ARIMA(1,0,1)(1,0,2)[2] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(1,0,1)(0,0,2)[2] intercept   : AIC=3768.982, Time=0.38 sec
#  ARIMA(1,0,1)(2,0,0)[2] intercept   : AIC=3695.811, Time=0.35 sec
#  ARIMA(1,0,1)(2,0,2)[2] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,1)(1,0,1)[2] intercept   : AIC=5648.238, Time=0.09 sec
#  ARIMA(1,0,0)(1,0,1)[2] intercept   : AIC=3713.115, Time=0.32 sec
#  ARIMA(0,0,0)(1,0,1)[2] intercept   : AIC=5680.488, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,1)[2]             : AIC=3673.776, Time=0.33 sec
#  ARIMA(1,0,1)(0,0,1)[2]             : AIC=3821.111, Time=0.22 sec
#  ARIMA(1,0,1)(1,0,0)[2]             : AIC=3701.086, Time=0.19 sec
#  ARIMA(1,0,1)(2,0,1)[2]             : AIC=3671.577, Time=0.32 sec
#  ARIMA(1,0,1)(2,0,0)[2]             : AIC=3689.881, Time=0.23 sec
#  ARIMA(1,0,1)(2,0,2)[2]             : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,1)(1,0,2)[2]             : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,1)(2,0,1)[2]             : AIC=5864.655, Time=0.23 sec
#  ARIMA(1,0,0)(2,0,1)[2]             : AIC=3670.340, Time=0.31 sec
#  ARIMA(1,0,0)(1,0,1)[2]             : AIC=3674.433, Time=0.15 sec
#  ARIMA(1,0,0)(2,0,0)[2]             : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,2)[2]             : AIC=3677.822, Time=0.37 sec
#  ARIMA(1,0,0)(1,0,0)[2]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,2)[2]             : AIC=3674.176, Time=0.27 sec
#  ARIMA(0,0,0)(2,0,1)[2]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,1)[2] intercept   : AIC=inf, Time=0.41 sec
#
# Best model:  ARIMA(1,0,0)(2,0,1)[2]
# Total fit time: 8.369 seconds
# Done

# %%
sarimax_case_results_data = pd.concat(case_results)
sarimax_case_results_data
# Out:
#             sarimax_cases_predicted  sarimax_cases_residuals      state
# 2020-11-07             98532.642988              1138.357012     Kansas
# 2020-11-08            102926.467115             -3121.467115     Kansas
# 2020-11-09            102275.195252              3022.804748     Kansas
# 2020-11-10            107084.046933             -1324.046933     Kansas
# 2020-11-11            106209.913016              4767.086984     Kansas
# ...                             ...                      ...        ...
# 2020-11-29            318137.718661             40671.281339  Tennessee
# 2020-11-30            320528.117096             45883.882904  Tennessee
# 2020-12-01            322417.436248             49562.563752  Tennessee
# 2020-12-02            324807.830131             51187.169869  Tennessee
# 2020-12-03            326697.145138             52981.854862  Tennessee
#
# [1485 rows x 3 columns]

# %%
sarimax_case_results_data.index.name = 'date'

# %%
sarimax_case_prediction_data = pd.concat(case_forecasts,ignore_index=True)
sarimax_case_prediction_data
# Out:
#            date  sarimax_cases_forecasted      state
# 0    2020-12-07                  164673.0     Kansas
# 1    2020-12-08                  164711.0     Kansas
# 2    2020-12-09                  169158.0     Kansas
# 3    2020-12-10                  169304.0     Kansas
# 4    2020-12-11                  173541.0     Kansas
# ...         ...                       ...        ...
# 4945 2021-03-02                  796629.0  Tennessee
# 4946 2021-03-03                  802361.0  Tennessee
# 4947 2021-03-04                  806509.0  Tennessee
# 4948 2021-03-05                  812241.0  Tennessee
# 4949 2021-03-06                  816389.0  Tennessee
#
# [4950 rows x 3 columns]

# %%
sarimax_case_prediction_data.set_index('date', inplace = True)

# %%
frames = [sarimax_case_results_data, sarimax_case_prediction_data]
sarimax_case_data = pd.concat(frames).reset_index()
sarimax_case_data
# Out:
#                      date  sarimax_cases_predicted  sarimax_cases_residuals  \
# 0     2020-11-07 00:00:00             98532.642988              1138.357012
# 1     2020-11-08 00:00:00            102926.467115             -3121.467115
# 2     2020-11-09 00:00:00            102275.195252              3022.804748
# 3     2020-11-10 00:00:00            107084.046933             -1324.046933
# 4     2020-11-11 00:00:00            106209.913016              4767.086984
# ...                   ...                      ...                      ...
# 6430  2021-03-02 00:00:00                      NaN                      NaN
# 6431  2021-03-03 00:00:00                      NaN                      NaN
# 6432  2021-03-04 00:00:00                      NaN                      NaN
# 6433  2021-03-05 00:00:00                      NaN                      NaN
# 6434  2021-03-06 00:00:00                      NaN                      NaN
#
#           state  sarimax_cases_forecasted
# 0        Kansas                       NaN
# 1        Kansas                       NaN
# 2        Kansas                       NaN
# 3        Kansas                       NaN
# 4        Kansas                       NaN
# ...         ...                       ...
# 6430  Tennessee                  796629.0
# 6431  Tennessee                  802361.0
# 6432  Tennessee                  806509.0
# 6433  Tennessee                  812241.0
# 6434  Tennessee                  816389.0
#
# [6435 rows x 5 columns]

# %%
sarimax_case_data.to_csv('Resources/sarimax_case_data.csv', index=True, date_format='%Y-%m-%d')

# %%
Death

# %%
# run cases_best_training_model on EVERY state to get a dictionary of models

case_results = []
case_forecasts = []
sarimax_case_rmse = []
case_models={}
case_splits={}
case_full_models={}

# loop through counties
i = 0 
while i < len(states_list):
    state=states_list[i]
    print(state)
    
    #get data for state     
    df= pd.read_sql(f"select * from states_cases where state = '{state}' and NOT 'date' ISNULL and cases != 'N'",conn)
    
    #     manipulate data as needed to run ML
    df['cases']  = pd.to_numeric(df['cases']).astype(np.int64)
    ML_Data=df[['date', 'cases']]
    ML_Data=ML_Data.dropna(how='any', axis=0)
    ML_Data=ML_Data.set_index('date')
    ML_Data=ML_Data.fillna(0)
    ML_Data.head()
  
    print(f' Currently processing {state}, number {i+1} of {len(states_list)} states')
    
    #  test train split
    end_train=today- timedelta(days=30)
    start_test=today- timedelta(days=29)
    train=ML_Data[:end_train]
    test=ML_Data[start_test:]
    case_splits.update({'state':states_list[i]})
    case_splits.update({'train':train})
    case_splits.update({'test':test})
    #     print(splits['test'].index)
    
    #   call fxn to determine model best params & run model with them
    #   cases_best_training_model(countyData)
    stepwise_fit = auto_arima(train, start_p = 1, start_q = 1, 
                          max_p = 10, max_q = 30, m = 2,
                          start_P = 0, seasonal = True, 
                          stationary=True,
                          trace = True, 
                          error_action ='ignore',   # we don't want to know if an order does not work 
                          suppress_warnings = True,  # we don't want convergence warnings 
                          stepwise = True)           # set to stepwise 
  
    # pull out the parameters of the best model for this county
    x=stepwise_fit.get_params()
    
    # override Q parameter if 0 to 1
    so=x['seasonal_order']
    so_slice1=so[ :2]
    if so[2]==0:
        so=so_slice1+ (1, 2)
        
     # runs model with best fit ARIMA params
    model = SARIMAX(train,
                    order = (x['order']),
                    seasonal_order =(so),
                    initialization='approximate_diffuse')

    result = model.fit()
    case_models.update({state: result})
    
    start = len(train) 
    end = len(train) + len(test) - 1

    # Predictions for the test set 
    predictions = result.predict(start, end)
    predicted_df = pd.DataFrame(data=predictions, columns=["sarimax_cases_predicted"])
    predicted_df['sarimax_cases_expected'] = test
    modeled_df = predicted_df.drop(columns='sarimax_cases_expected')
    
    #     # Calculate rmse and store
    #     rmse = sqrt(mean_squared_error(predicted_df['sarimax_cases_expected'], predicted_df['sarimax_cases_predicted']))
    #     sarimax_case_rmse.append(rmse)
    
    # Calculate residuals
    residuals = predicted_df['sarimax_cases_expected'] - predicted_df['sarimax_cases_predicted']
    residuals_df = pd.DataFrame(data=residuals, columns=["sarimax_cases_residuals"])
    
    # Put everything together in dataframe  
    results_df = modeled_df.join(residuals_df)
    results_df['state']=state
    case_results.append(results_df)
    
    #  get results for full dataset:
    end_full=today- timedelta(days=5)
    start_full=today- timedelta(days=230)
    formodel=ML_Data[start_full:end_full]

    #   cases_best_training_model for full data
    stepwise_fit_full = auto_arima(formodel, start_p = 1, start_q = 1, 
                                   max_p = 10, max_q = 30, m = 2,
                                   start_P = 0, seasonal = True, 
                                   stationary=True,
                                   trace = True, 
                                   error_action ='ignore',   # we don't want to know if an order does not work 
                                   suppress_warnings = True,  # we don't want convergence warnings 
                                   stepwise = True)           # set to stepwise 
    
    # pull out the parameters of the best model for this county
    x_full=stepwise_fit_full.get_params()
    
    # override Q parameter if 0 to 1
    so_full=x_full['seasonal_order']
    so_full_slice1=so_full[ :2]
    if so_full[2]==0:
        so_full=so_full_slice1+ (1, 2)
    
    # runs model with best fit ARIMA params
    full_model = SARIMAX(formodel,
                    order = (x_full['order']),
                    seasonal_order =(so_full),
                    initialization='approximate_diffuse')

    full_result = full_model.fit()
    case_full_models.update({state: full_result})
    
    # Getting 90 days for forecasts and store
    SARIMAX_forecast = round(full_result.forecast(steps = 90))
    endforecast=tomorrow + timedelta(days=90)
    idx = pd.date_range(tomorrow, endforecast, freq='d')
    SARIMAX_forecast = pd.DataFrame(list(zip(list(idx),list(SARIMAX_forecast))),
                                    columns=['date','sarimax_cases_forecasted'])
    SARIMAX_forecast['state']=state
    case_forecasts.append(SARIMAX_forecast)
    
    i = i + 1
    print("Done")
