# %% [markdown]
# # TESTING DB CONNECTION AND VIEWS

# %%
# Install Dependencies
import pandas as pd
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

from numpy import concatenate
from math import sqrt
from statsmodels.graphics.gofplots import qqplot
from pandas.plotting import autocorrelation_plot

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
from flask import Flask, jsonify, render_template

import json

import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from pmdarima import auto_arima 
import statsmodels.api as sm
import plotly.express as px
import plotly as py

# %%
engine = create_engine("postgres://hdsqfkpfyrmcls:44d0c2afaa4b73f05e08bd94b4604fdb7b43432e1260f0ee78d4fbf9adae54d2@ec2-34-239-241-25.compute-1.amazonaws.com:5432/ddnn9438k8o9n9", echo=False)
conn = engine.connect()

# %%
from datetime import date, timedelta

today = date.today()
today
yesterday = today - timedelta(days = 1)
yesterday
tomorrow= today + timedelta(days = 1)
tomorrow
lala=today- timedelta(days=230)
lala
# Out:
# datetime.date(2020, 4, 23)

# %%
states_list_df = pd.read_sql("select distinct state from states_cases WHERE NOT state = 'None'",conn).sort_values('state')
states_list= states_list_df['state']
states_list
# Out:
# 5                      Alabama
# 4                       Alaska
# 41                     Arizona
# 24                    Arkansas
# 53                  California
# 8                     Colorado
# 26                 Connecticut
# 13                    Delaware
# 28        District of Columbia
# 10                     Florida
# 46                     Georgia
# 18                        Guam
# 23                      Hawaii
# 3                        Idaho
# 42                    Illinois
# 30                     Indiana
# 29                        Iowa
# 0                       Kansas
# 40                    Kentucky
# 16                   Louisiana
# 52                       Maine
# 44                    Maryland
# 31               Massachusetts
# 34                    Michigan
# 35                   Minnesota
# 9                  Mississippi
# 25                    Missouri
# 39                     Montana
# 51                    Nebraska
# 15                      Nevada
# 49               New Hampshire
# 21                  New Jersey
# 22                  New Mexico
# 17                    New York
# 7               North Carolina
# 50                North Dakota
# 14    Northern Mariana Islands
# 33                        Ohio
# 6                     Oklahoma
# 2                       Oregon
# 36                Pennsylvania
# 45                 Puerto Rico
# 32                Rhode Island
# 20              South Carolina
# 27                South Dakota
# 54                   Tennessee
# 1                        Texas
# 48                        Utah
# 12                     Vermont
# 11              Virgin Islands
# 43                    Virginia
# 37                  Washington
# 19               West Virginia
# 38                   Wisconsin
# 47                     Wyoming
# Name: state, dtype: object

# %%
# run cases_best_training_model on EVERY state to get a dictionary of models

case_results = []
case_forecasts = []
sarimax_case_rmse = []
case_models={}
case_splits={}
case_full_models={}

# loop through counties
i = 0 
while i < len(states_list):
    state=states_list[i]
    print(state)
    
    #get data for state     
    df= pd.read_sql(f"select * from states_cases where state = '{state}' and NOT 'date' ISNULL and cases != 'N'",conn)
    
    #     manipulate data as needed to run ML
    df['cases']  = pd.to_numeric(df['cases']).astype(np.int64)
    ML_Data=df[['date', 'cases']]
#     ML_Data=ML_Data.dropna(how='any', axis=0)
#     ML_Data=ML_Data.set_index('date')
    ML_Data=ML_Data.fillna(0)
    print(f'ML_Data: {ML_Data}')
  
    print(f' Currently processing {state}, number {i+1} of {len(states_list)} states')
    
    #  test train split
#     end_train=today- timedelta(days=30)
#     start_test=today- timedelta(days=29)
#     train=ML_Data.cases[:299]
#     test=ML_Data.cases[300:]
# #     train=ML_Data[:end_train]
# #     test=ML_Data[start_test:]
#     case_splits.update({'state':states_list[i]})
#     case_splits.update({'train':train})
#     case_splits.update({'test':test})
#     print(case_splits['test'].index)
    
    #   call fxn to determine model best params & run model with them
    #   cases_best_training_model(countyData)
#     stepwise_fit = auto_arima(train, start_p = 1, start_q = 1, 
#                           max_p = 10, max_q = 30, m = 2,
#                           start_P = 0, seasonal = True, 
#                           stationary=True,
#                           trace = True, 
#                           error_action ='ignore',   # we don't want to know if an order does not work 
#                           suppress_warnings = True,  # we don't want convergence warnings 
#                           stepwise = True)           # set to stepwise 
#     stepwise_fit = auto_arima(ML_Data.cases, start_p = 1, start_q = 1, 
#                                    max_p = 14, max_q = 30, m = 7,
#                                    start_P = 1, 
#                                    d=2,
#                                    D=2,
#                                    max_order =28,
#                                    seasonal = True, 
# #                                    stationary=True,
#                                    trace = True, 
#                                    with_intercept=True,
#                                    error_action ='ignore',   # we don't want to know if an order does not work 
#                                    suppress_warnings = True,  # we don't want convergence warnings 
#                                    stepwise = True) 
  
#     # pull out the parameters of the best model for this county
#     x=stepwise_fit.get_params()
    
    # override Q parameter if 0 to 1
#     so=x['seasonal_order']
#     #     so_slice1=so[ :2]
#     #     if so[2]==0:
#     #         so=so_slice1+ (1, 2)
        
#      # runs model with best fit ARIMA params
#     model = SARIMAX(train,
#                     order = (x['order']),
#                     seasonal_order =(so),
#                     initialization='approximate_diffuse')

#     result = model.fit()
#     case_models.update({state: result})
    
#     start = len(train) 
#     end = len(train) + len(test) - 1

#     # Predictions for the test set 
#     predictions = result.predict(start, end)
#     predicted_df = pd.DataFrame(data=predictions, columns=["sarimax_cases_predicted"])
# #     predicted_df['sarimax_cases_expected'] = test
    
#     predicted_df['sarimax_cases_expected'] = ML_Data.cases[299:]
#     predicted_df['date']=ML_Data.date[299:]
#     predicted_df=predicted_df.set_index('date') 
    
#     modeled_df = predicted_df.drop(columns='sarimax_cases_expected')
#     #     # Calculate rmse and store
#     rmse = sqrt(mean_squared_error(predicted_df['sarimax_cases_expected'], predicted_df['sarimax_cases_predicted']))
#     sarimax_case_rmse.append(rmse)
    
#     # Calculate residuals
#     residuals = predicted_df['sarimax_cases_expected'] - predicted_df['sarimax_cases_predicted']
#     residuals_df = pd.DataFrame(data=residuals, columns=["sarimax_cases_residuals"])
    
#     # Put everything together in dataframe  
#     results_df = modeled_df.join(residuals_df)
#     results_df['state']=state
#     case_results.append(results_df)
    
    #  get results for full dataset:
#     end_full=yesterday
#     start_full=pd.to_datetime('2020-05-01')
#     #     formodel=ML_Data[start_full:end_full]
#     formodel= ML_Data

    #   cases_best_training_model for full data
    stepwise_fit_full = auto_arima(ML_Data.cases, start_p = 1, start_q = 1, 
                                   max_p = 14, max_q = 30, m = 7,
                                   start_P = 1, 
                                   d=2,
                                   D=2,
                                   max_order =28,
                                   seasonal = True, 
#                                    stationary=True,
                                   trace = True, 
                                   with_intercept= True,
                                   error_action ='ignore',   # we don't want to know if an order does not work 
                                   suppress_warnings = True,  # we don't want convergence warnings 
                                   stepwise = True)           # set to stepwise 
    
    # pull out the parameters of the best model for this county
    x_full=stepwise_fit_full.get_params()
    
    # override Q parameter if 0 to 1
    so_full=x_full['seasonal_order']
#     so_full_slice1=so_full[ :2]
#     if so_full[2]==0:
#         so_full=so_full_slice1+ (1, 2)
    
    # runs model with best fit ARIMA params
    full_model = SARIMAX(ML_Data.cases,
                    order = (x_full['order']),
                    seasonal_order =(so_full),
                    initialization='approximate_diffuse')

    full_result = full_model.fit()
    case_full_models.update({state: full_result})
    
    # Getting 90 days for forecasts and store
    SARIMAX_forecast = round(full_result.forecast(steps = 90))
    endforecast=tomorrow + timedelta(days=90)
    idx = pd.date_range(tomorrow, endforecast, freq='d')
    SARIMAX_forecast = pd.DataFrame(list(zip(list(idx),list(SARIMAX_forecast))),
                                    columns=['date','sarimax_cases_forecasted'])
    SARIMAX_forecast['state']=state
    case_forecasts.append(SARIMAX_forecast)
    
    i = i + 1
    print("Done")
# Out:
# Kansas
# ML_Data:            date   cases
# 0    2020-02-18       0
# 1    2020-02-19       0
# 2    2020-02-20       0
# 3    2020-02-21       0
# 4    2020-01-21       0
# ..          ...     ...
# 317  2020-12-03  165613
# 318  2020-12-04  171513
# 319  2020-12-05  171626
# 320  2020-12-06  171635
# 321  2020-12-07  177389
#
# [322 rows x 2 columns]
#  Currently processing Kansas, number 1 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4786.665, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4591.967, Time=0.51 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4784.745, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4701.818, Time=0.06 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4583.663, Time=0.89 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.80 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4703.629, Time=0.66 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4530.047, Time=1.26 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4542.620, Time=0.57 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.48 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4529.229, Time=1.60 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4540.934, Time=0.76 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.87 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.83 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=4509.175, Time=2.62 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=4519.553, Time=1.19 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.10 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.81 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=4509.744, Time=3.63 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=4510.118, Time=4.04 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=4516.572, Time=6.37 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=4511.658, Time=6.37 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=4507.193, Time=2.76 sec
#  ARIMA(4,2,0)(1,2,0)[7]             : AIC=4517.655, Time=1.15 sec
#  ARIMA(4,2,0)(2,2,1)[7]             : AIC=inf, Time=5.27 sec
#  ARIMA(4,2,0)(1,2,1)[7]             : AIC=inf, Time=1.65 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=4527.226, Time=1.59 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=4507.759, Time=3.02 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=4508.157, Time=4.22 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=3.32 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=4509.783, Time=6.30 sec
#
# Best model:  ARIMA(4,2,0)(2,2,0)[7]
# Total fit time: 85.302 seconds
# Done
# Texas
# ML_Data:            date    cases
# 0    2020-01-21        0
# 1    2020-01-22        0
# 2    2020-01-23        0
# 3    2020-01-24        0
# 4    2020-01-25        0
# ..          ...      ...
# 317  2020-12-03  1310534
# 318  2020-12-04  1322711
# 319  2020-12-05  1333809
# 320  2020-12-06  1344195
# 321  2020-12-07  1358215
#
# [322 rows x 2 columns]
#  Currently processing Texas, number 2 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.86 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=6128.344, Time=0.04 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5889.419, Time=0.81 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=6126.751, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=6058.085, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=5797.112, Time=1.49 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=5744.886, Time=3.08 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(1,2,0)(2,2,2)[7] intercept   : AIC=5813.781, Time=2.97 sec
#  ARIMA(1,2,0)(1,2,2)[7] intercept   : AIC=5738.417, Time=2.44 sec
#  ARIMA(1,2,0)(0,2,2)[7] intercept   : AIC=inf, Time=2.24 sec
#  ARIMA(1,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(0,2,0)(1,2,2)[7] intercept   : AIC=5875.941, Time=1.86 sec
#  ARIMA(2,2,0)(1,2,2)[7] intercept   : AIC=5803.700, Time=2.85 sec
#  ARIMA(1,2,1)(1,2,2)[7] intercept   : AIC=inf, Time=4.24 sec
#  ARIMA(0,2,1)(1,2,2)[7] intercept   : AIC=5573.239, Time=4.04 sec
#  ARIMA(0,2,1)(0,2,2)[7] intercept   : AIC=inf, Time=3.39 sec
#  ARIMA(0,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.79 sec
#  ARIMA(0,2,1)(2,2,2)[7] intercept   : AIC=inf, Time=4.43 sec
#  ARIMA(0,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=2.78 sec
#  ARIMA(0,2,2)(1,2,2)[7] intercept   : AIC=5764.463, Time=4.65 sec
#  ARIMA(1,2,2)(1,2,2)[7] intercept   : AIC=inf, Time=5.29 sec
#  ARIMA(0,2,1)(1,2,2)[7]             : AIC=inf, Time=4.11 sec
#
# Best model:  ARIMA(0,2,1)(1,2,2)[7] intercept
# Total fit time: 58.371 seconds
# Done
# Oregon
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03  79294
# 318  2020-12-04  81441
# 319  2020-12-05  83243
# 320  2020-12-06  84496
# 321  2020-12-07  85803
#
# [322 rows x 2 columns]
#  Currently processing Oregon, number 3 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4235.539, Time=0.04 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4004.378, Time=0.66 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4233.541, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4131.379, Time=0.10 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3925.228, Time=1.84 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.07 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4031.702, Time=0.77 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3868.836, Time=2.75 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3945.735, Time=1.09 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.86 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.56 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3852.054, Time=3.38 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3932.928, Time=1.40 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.51 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3849.858, Time=4.16 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3932.056, Time=1.71 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.71 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.81 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3842.066, Time=5.18 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3913.610, Time=2.10 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.51 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.61 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3841.420, Time=4.17 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=3907.333, Time=3.00 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.81 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.03 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.45 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.45 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=3839.519, Time=1.64 sec
#  ARIMA(6,2,0)(1,2,0)[7]             : AIC=3905.471, Time=1.63 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=4.87 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=3.30 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3840.196, Time=1.66 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=6.84 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=7.69 sec
#
# Best model:  ARIMA(6,2,0)(2,2,0)[7]
# Total fit time: 116.040 seconds
# Done
# Idaho
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  106882
# 318  2020-12-04  108741
# 319  2020-12-05  109764
# 320  2020-12-06  110553
# 321  2020-12-07  112433
#
# [322 rows x 2 columns]
#  Currently processing Idaho, number 4 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.15 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4603.152, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.12 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4601.162, Time=0.03 sec
#  ARIMA(0,2,0)(1,2,0)[7] intercept   : AIC=4423.945, Time=0.35 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4306.750, Time=0.79 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.33 sec
#  ARIMA(0,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4159.458, Time=1.68 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.91 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4143.000, Time=2.01 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.94 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.42 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4115.922, Time=4.11 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4230.097, Time=1.72 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.68 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.68 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=4110.317, Time=3.82 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=4207.457, Time=1.84 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=4080.070, Time=6.60 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(4,2,0)(2,2,2)[7] intercept   : AIC=4025.718, Time=6.72 sec
#  ARIMA(4,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=3.44 sec
#  ARIMA(3,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=5.78 sec
#  ARIMA(5,2,0)(2,2,2)[7] intercept   : AIC=4112.177, Time=6.86 sec
#  ARIMA(4,2,1)(2,2,2)[7] intercept   : AIC=inf, Time=3.75 sec
#  ARIMA(3,2,1)(2,2,2)[7] intercept   : AIC=inf, Time=7.53 sec
#  ARIMA(5,2,1)(2,2,2)[7] intercept   : AIC=inf, Time=9.46 sec
#  ARIMA(4,2,0)(2,2,2)[7]             : AIC=inf, Time=6.59 sec
#
# Best model:  ARIMA(4,2,0)(2,2,2)[7] intercept
# Total fit time: 100.689 seconds
# Done
# Alaska
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03  34377
# 318  2020-12-04  35138
# 319  2020-12-05  36083
# 320  2020-12-06  36847
# 321  2020-12-07  37350
#
# [322 rows x 2 columns]
#  Currently processing Alaska, number 5 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3552.010, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3334.275, Time=0.34 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3550.010, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=3482.721, Time=0.12 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3241.756, Time=0.83 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3265.699, Time=0.68 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3240.111, Time=1.86 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3336.072, Time=0.68 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.24 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3236.160, Time=1.86 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3331.099, Time=1.16 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3233.300, Time=2.38 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3331.787, Time=1.44 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.06 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.44 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3222.949, Time=4.28 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3315.011, Time=1.61 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.28 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3223.675, Time=5.65 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=3.50 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=3.95 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.64 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3220.962, Time=1.52 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=3313.057, Time=0.54 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=2.91 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=1.22 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=3231.307, Time=0.80 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=3221.686, Time=2.21 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=2.40 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=2.83 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=7.10 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 82.302 seconds
# Done
# Alabama
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  260359
# 318  2020-12-04  264199
# 319  2020-12-05  267589
# 320  2020-12-06  269877
# 321  2020-12-07  272229
#
# [322 rows x 2 columns]
#  Currently processing Alabama, number 6 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5194.363, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4857.090, Time=0.63 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5192.365, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5089.276, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4755.912, Time=1.62 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4815.176, Time=1.29 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4740.756, Time=3.00 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4830.486, Time=0.87 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.83 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.64 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4731.271, Time=4.65 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4829.067, Time=1.04 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.92 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.02 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=4730.461, Time=3.97 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=4826.129, Time=1.21 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.69 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.35 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=4720.735, Time=5.53 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=4820.950, Time=1.69 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=4593.990, Time=8.68 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=4652.461, Time=3.51 sec
#  ARIMA(5,2,0)(2,2,2)[7] intercept   : AIC=4663.127, Time=7.87 sec
#  ARIMA(5,2,0)(1,2,2)[7] intercept   : AIC=4724.160, Time=3.95 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=7.96 sec
#  ARIMA(5,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=7.79 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=4699.606, Time=6.09 sec
#  ARIMA(6,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=8.22 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=5.84 sec
#
# Best model:  ARIMA(5,2,0)(2,2,1)[7] intercept
# Total fit time: 111.572 seconds
# Done
# Oklahoma
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  204048
# 318  2020-12-04  208875
# 319  2020-12-05  213245
# 320  2020-12-06  216486
# 321  2020-12-07  218389
#
# [322 rows x 2 columns]
#  Currently processing Oklahoma, number 7 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.84 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5262.376, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4988.129, Time=0.68 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5260.379, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5154.190, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(1,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=4685.728, Time=2.24 sec
#  ARIMA(1,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=2.69 sec
#  ARIMA(1,2,0)(1,2,2)[7] intercept   : AIC=4716.850, Time=2.94 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.42 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=4648.220, Time=4.09 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.01 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4731.396, Time=2.28 sec
#  ARIMA(2,2,0)(2,2,2)[7] intercept   : AIC=4671.193, Time=5.51 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4890.222, Time=1.21 sec
#  ARIMA(2,2,0)(1,2,2)[7] intercept   : AIC=4704.328, Time=3.17 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=4657.172, Time=5.93 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=4618.611, Time=5.71 sec
#  ARIMA(2,2,1)(1,2,1)[7] intercept   : AIC=4717.483, Time=2.21 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=4697.622, Time=5.65 sec
#  ARIMA(2,2,1)(2,2,2)[7] intercept   : AIC=4737.228, Time=6.03 sec
#  ARIMA(2,2,1)(1,2,0)[7] intercept   : AIC=4841.339, Time=1.75 sec
#  ARIMA(2,2,1)(1,2,2)[7] intercept   : AIC=4634.411, Time=6.02 sec
#  ARIMA(1,2,1)(2,2,1)[7] intercept   : AIC=4804.455, Time=3.38 sec
#  ARIMA(3,2,1)(2,2,1)[7] intercept   : AIC=4697.734, Time=6.73 sec
#  ARIMA(2,2,2)(2,2,1)[7] intercept   : AIC=4754.107, Time=5.92 sec
#  ARIMA(1,2,2)(2,2,1)[7] intercept   : AIC=4779.989, Time=3.68 sec
#  ARIMA(3,2,2)(2,2,1)[7] intercept   : AIC=inf, Time=6.29 sec
#  ARIMA(2,2,1)(2,2,1)[7]             : AIC=inf, Time=4.58 sec
#
# Best model:  ARIMA(2,2,1)(2,2,1)[7] intercept
# Total fit time: 98.863 seconds
# Done
# North Carolina
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  378370
# 318  2020-12-04  384165
# 319  2020-12-05  388760
# 320  2020-12-06  395020
# 321  2020-12-07  399796
#
# [322 rows x 2 columns]
#  Currently processing North Carolina, number 8 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.84 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5379.116, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5089.016, Time=0.80 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5377.121, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5235.299, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4957.889, Time=1.43 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=4836.464, Time=2.79 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.57 sec
#  ARIMA(1,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=3.41 sec
#  ARIMA(1,2,0)(1,2,2)[7] intercept   : AIC=4931.342, Time=2.53 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=4993.467, Time=2.24 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=4830.127, Time=4.30 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.73 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4902.791, Time=3.70 sec
#  ARIMA(2,2,0)(2,2,2)[7] intercept   : AIC=4906.922, Time=4.57 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=5026.297, Time=0.82 sec
#  ARIMA(2,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=2.81 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=4857.190, Time=5.33 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=4.67 sec
#  ARIMA(1,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=3.04 sec
#  ARIMA(3,2,1)(2,2,1)[7] intercept   : AIC=4898.053, Time=5.93 sec
#  ARIMA(2,2,0)(2,2,1)[7]             : AIC=inf, Time=3.73 sec
#
# Best model:  ARIMA(2,2,0)(2,2,1)[7] intercept
# Total fit time: 58.472 seconds
# Done
# Colorado
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  248779
# 318  2020-12-04  252960
# 319  2020-12-05  258124
# 320  2020-12-06  262460
# 321  2020-12-07  266670
#
# [322 rows x 2 columns]
#  Currently processing Colorado, number 9 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.04 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4653.263, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4466.311, Time=0.64 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4651.266, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4628.710, Time=0.06 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4426.167, Time=1.09 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4433.992, Time=0.69 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4403.639, Time=2.27 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4446.702, Time=0.84 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=4334.835, Time=4.94 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.14 sec
#  ARIMA(2,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=4.95 sec
#  ARIMA(2,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=3.07 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=4307.494, Time=6.66 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4397.718, Time=2.78 sec
#  ARIMA(3,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=5.68 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4444.687, Time=0.90 sec
#  ARIMA(3,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=2.96 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=4349.856, Time=6.49 sec
#  ARIMA(3,2,1)(2,2,1)[7] intercept   : AIC=4390.164, Time=5.92 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=5.16 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=7.63 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=3.21 sec
#
# Best model:  ARIMA(3,2,0)(2,2,1)[7] intercept
# Total fit time: 76.305 seconds
# Done
# Mississippi
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  159036
# 318  2020-12-04  161516
# 319  2020-12-05  163458
# 320  2020-12-06  164931
# 321  2020-12-07  166194
#
# [322 rows x 2 columns]
#  Currently processing Mississippi, number 10 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.80 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4766.845, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4526.373, Time=0.43 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4764.856, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4714.014, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4425.640, Time=0.80 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4488.800, Time=1.02 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4401.311, Time=1.85 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4491.885, Time=1.08 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.38 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.03 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4393.664, Time=2.23 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4478.049, Time=0.91 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.81 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=4281.698, Time=2.37 sec
#  ARIMA(3,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(3,2,0)(1,2,2)[7] intercept   : AIC=4239.641, Time=3.14 sec
#  ARIMA(3,2,0)(0,2,2)[7] intercept   : AIC=4238.443, Time=3.08 sec
#  ARIMA(2,2,0)(0,2,2)[7] intercept   : AIC=4249.232, Time=2.42 sec
#  ARIMA(4,2,0)(0,2,2)[7] intercept   : AIC=4234.124, Time=3.13 sec
#  ARIMA(4,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=1.86 sec
#  ARIMA(4,2,0)(1,2,2)[7] intercept   : AIC=4339.029, Time=3.92 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.99 sec
#  ARIMA(5,2,0)(0,2,2)[7] intercept   : AIC=4230.096, Time=4.14 sec
#  ARIMA(5,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(5,2,0)(1,2,2)[7] intercept   : AIC=4294.772, Time=4.62 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.55 sec
#  ARIMA(6,2,0)(0,2,2)[7] intercept   : AIC=4246.135, Time=4.73 sec
#  ARIMA(5,2,1)(0,2,2)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(4,2,1)(0,2,2)[7] intercept   : AIC=inf, Time=8.46 sec
#  ARIMA(6,2,1)(0,2,2)[7] intercept   : AIC=inf, Time=6.56 sec
#  ARIMA(5,2,0)(0,2,2)[7]             : AIC=inf, Time=1.31 sec
#
# Best model:  ARIMA(5,2,0)(0,2,2)[7] intercept
# Total fit time: 87.644 seconds
# Done
# Florida
# ML_Data:            date    cases
# 0    2020-01-21        0
# 1    2020-01-22        0
# 2    2020-01-23        0
# 3    2020-01-24        0
# 4    2020-01-25        0
# ..          ...      ...
# 317  2020-12-03  1029022
# 318  2020-12-04  1039199
# 319  2020-12-05  1049630
# 320  2020-12-06  1058066
# 321  2020-12-07  1065777
#
# [322 rows x 2 columns]
#  Currently processing Florida, number 11 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.67 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5984.813, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5623.132, Time=0.66 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5983.072, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5799.671, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=5567.365, Time=1.34 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=5466.767, Time=2.61 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.24 sec
#  ARIMA(1,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=2.98 sec
#  ARIMA(1,2,0)(1,2,2)[7] intercept   : AIC=5527.162, Time=2.40 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=5379.368, Time=4.09 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=5464.625, Time=1.64 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=5502.339, Time=3.03 sec
#  ARIMA(2,2,0)(2,2,2)[7] intercept   : AIC=5510.916, Time=4.65 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=5557.717, Time=1.22 sec
#  ARIMA(2,2,0)(1,2,2)[7] intercept   : AIC=5521.388, Time=2.66 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=5363.780, Time=5.06 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=5366.475, Time=1.99 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=5466.145, Time=4.37 sec
#  ARIMA(3,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=5.30 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=inf, Time=1.41 sec
#  ARIMA(3,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=2.79 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=5386.688, Time=6.34 sec
#  ARIMA(3,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=5.74 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=5433.950, Time=5.87 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=5427.398, Time=6.85 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=4.86 sec
#
# Best model:  ARIMA(3,2,0)(2,2,1)[7] intercept
# Total fit time: 83.683 seconds
# Done
# Virgin Islands
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03   1589
# 318  2020-12-04   1613
# 319  2020-12-05   1613
# 320  2020-12-06   1613
# 321  2020-12-07   1649
#
# [322 rows x 2 columns]
#  Currently processing Virgin Islands, number 12 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.36 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3025.935, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2607.367, Time=0.36 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3023.940, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2786.873, Time=0.11 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2569.661, Time=0.96 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.08 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2725.623, Time=0.56 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2551.157, Time=1.63 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2582.715, Time=0.75 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.23 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2540.240, Time=2.08 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2573.672, Time=0.85 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2535.444, Time=2.42 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2567.552, Time=0.97 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.44 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2528.333, Time=2.90 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2561.678, Time=1.39 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.52 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2496.892, Time=6.77 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=2558.816, Time=1.16 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.94 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.96 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=2513.797, Time=4.33 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.67 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=2494.912, Time=2.79 sec
#  ARIMA(6,2,0)(1,2,0)[7]             : AIC=2556.830, Time=0.55 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=6.24 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=2.71 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2526.351, Time=0.80 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=2511.812, Time=1.55 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.02 sec
#
# Best model:  ARIMA(6,2,0)(2,2,0)[7]
# Total fit time: 88.607 seconds
# Done
# Vermont
# ML_Data:            date  cases
# 0    2020-02-24      0
# 1    2020-02-25      0
# 2    2020-02-26      0
# 3    2020-01-21      0
# 4    2020-01-22      0
# ..          ...    ...
# 317  2020-12-03   4642
# 318  2020-12-04   4763
# 319  2020-12-05   4894
# 320  2020-12-06   5015
# 321  2020-12-07   5080
#
# [322 rows x 2 columns]
#  Currently processing Vermont, number 13 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.92 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3179.170, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2954.760, Time=0.38 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3177.170, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=3041.867, Time=0.11 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2886.458, Time=1.05 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2966.662, Time=0.95 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2817.488, Time=1.85 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2917.158, Time=1.05 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.94 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.10 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2817.500, Time=4.01 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=2817.301, Time=3.45 sec
#  ARIMA(2,2,1)(1,2,0)[7] intercept   : AIC=2918.572, Time=1.35 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=4.51 sec
#  ARIMA(2,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(1,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=2.88 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.63 sec
#  ARIMA(2,2,2)(2,2,0)[7] intercept   : AIC=2810.191, Time=3.92 sec
#  ARIMA(2,2,2)(1,2,0)[7] intercept   : AIC=2901.480, Time=2.27 sec
#  ARIMA(2,2,2)(2,2,1)[7] intercept   : AIC=inf, Time=4.77 sec
#  ARIMA(2,2,2)(1,2,1)[7] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(1,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=2.54 sec
#  ARIMA(3,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=5.25 sec
#  ARIMA(2,2,3)(2,2,0)[7] intercept   : AIC=inf, Time=5.48 sec
#  ARIMA(1,2,3)(2,2,0)[7] intercept   : AIC=2825.545, Time=2.45 sec
#  ARIMA(3,2,3)(2,2,0)[7] intercept   : AIC=inf, Time=4.95 sec
#  ARIMA(2,2,2)(2,2,0)[7]             : AIC=2808.257, Time=1.53 sec
#  ARIMA(2,2,2)(1,2,0)[7]             : AIC=2899.500, Time=1.15 sec
#  ARIMA(2,2,2)(2,2,1)[7]             : AIC=inf, Time=3.46 sec
#  ARIMA(2,2,2)(1,2,1)[7]             : AIC=inf, Time=1.29 sec
#  ARIMA(1,2,2)(2,2,0)[7]             : AIC=inf, Time=2.00 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=2815.308, Time=0.78 sec
#  ARIMA(3,2,2)(2,2,0)[7]             : AIC=inf, Time=4.49 sec
#  ARIMA(2,2,3)(2,2,0)[7]             : AIC=inf, Time=4.76 sec
#  ARIMA(1,2,1)(2,2,0)[7]             : AIC=inf, Time=1.63 sec
#  ARIMA(1,2,3)(2,2,0)[7]             : AIC=2823.560, Time=0.82 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=3.25 sec
#  ARIMA(3,2,3)(2,2,0)[7]             : AIC=inf, Time=4.86 sec
#
# Best model:  ARIMA(2,2,2)(2,2,0)[7]
# Total fit time: 100.805 seconds
# Done
# Delaware
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03  37456
# 318  2020-12-04  38398
# 319  2020-12-05  39096
# 320  2020-12-06  39912
# 321  2020-12-07  40711
#
# [322 rows x 2 columns]
#  Currently processing Delaware, number 14 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.21 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4112.579, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3819.756, Time=0.40 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4110.592, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4020.378, Time=0.08 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3734.113, Time=0.76 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.33 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3817.574, Time=0.58 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3693.905, Time=1.95 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3761.193, Time=0.63 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.34 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3681.934, Time=2.40 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3753.240, Time=0.80 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.35 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.19 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3665.725, Time=2.57 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3735.069, Time=0.95 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.68 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3660.828, Time=2.89 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3728.305, Time=1.28 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=8.42 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.98 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3659.680, Time=3.65 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=3716.745, Time=1.70 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.79 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.42 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.90 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.58 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=3657.834, Time=1.38 sec
#  ARIMA(6,2,0)(1,2,0)[7]             : AIC=3714.895, Time=0.71 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=3.65 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=1.59 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3658.982, Time=0.95 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=2.95 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.44 sec
#
# Best model:  ARIMA(6,2,0)(2,2,0)[7]
# Total fit time: 95.518 seconds
# Done
# Northern Mariana Islands
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03    106
# 318  2020-12-04    106
# 319  2020-12-05    106
# 320  2020-12-06    106
# 321  2020-12-07    109
#
# [322 rows x 2 columns]
#  Currently processing Northern Mariana Islands, number 15 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.83 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=1509.822, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1303.121, Time=0.18 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=1507.822, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=1431.699, Time=0.07 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1210.121, Time=0.49 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.63 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.16 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1307.536, Time=0.33 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1169.231, Time=0.86 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1261.288, Time=0.35 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.37 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.75 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1159.567, Time=0.92 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1249.681, Time=0.48 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.52 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.62 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1135.388, Time=1.10 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=1216.658, Time=0.55 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=8.35 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.02 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=1125.077, Time=1.36 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=1192.203, Time=0.62 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.57 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.07 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=1125.608, Time=1.66 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.81 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.36 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=1127.590, Time=4.30 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=1123.083, Time=0.71 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=1190.205, Time=0.33 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=5.62 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=1.91 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=1133.393, Time=0.52 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=1123.614, Time=0.86 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=4.94 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.96 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=1125.596, Time=1.66 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 86.200 seconds
# Done
# Nevada
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  160317
# 318  2020-12-04  163065
# 319  2020-12-05  166187
# 320  2020-12-06  168758
# 321  2020-12-07  171159
#
# [322 rows x 2 columns]
#  Currently processing Nevada, number 16 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4696.606, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4410.588, Time=0.47 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.45 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4694.610, Time=0.04 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4621.296, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4295.215, Time=0.93 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.44 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4359.268, Time=0.78 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4271.812, Time=1.82 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4380.122, Time=1.22 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.31 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.76 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4271.154, Time=2.29 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4382.023, Time=1.57 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=4148.115, Time=5.14 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=4187.391, Time=2.28 sec
#  ARIMA(3,2,0)(2,2,2)[7] intercept   : AIC=4286.020, Time=5.46 sec
#  ARIMA(3,2,0)(1,2,2)[7] intercept   : AIC=4153.359, Time=3.01 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=4178.531, Time=1496.64 sec
#  ARIMA(3,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=8.57 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=4186.450, Time=5.10 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=6.72 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=2.65 sec
#
# Best model:  ARIMA(3,2,0)(2,2,1)[7] intercept
# Total fit time: 1556.879 seconds
# Done
# Louisiana
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  244078
# 318  2020-12-04  247177
# 319  2020-12-05  247177
# 320  2020-12-06  251123
# 321  2020-12-07  252136
#
# [322 rows x 2 columns]
#  Currently processing Louisiana, number 17 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.99 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5326.434, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5142.842, Time=0.56 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.26 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5324.439, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5256.781, Time=0.06 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=5076.995, Time=1.21 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.79 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.34 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=5153.669, Time=0.97 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=5036.535, Time=1.88 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=5087.488, Time=0.75 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.81 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.91 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=5012.271, Time=2.05 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=5075.787, Time=0.90 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=4896.177, Time=5.22 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=4963.125, Time=1.99 sec
#  ARIMA(3,2,0)(2,2,2)[7] intercept   : AIC=5003.464, Time=5.14 sec
#  ARIMA(3,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=3.09 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.02 sec
#  ARIMA(3,2,1)(2,2,1)[7] intercept   : AIC=4965.665, Time=5.73 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=4922.425, Time=5.00 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=4977.605, Time=6.36 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=3.33 sec
#
# Best model:  ARIMA(3,2,0)(2,2,1)[7] intercept
# Total fit time: 63.445 seconds
# Done
# New York
# ML_Data:            date   cases
# 0    2020-01-26       0
# 1    2020-01-27       0
# 2    2020-01-28       0
# 3    2020-01-29       0
# 4    2020-01-30       0
# ..          ...     ...
# 317  2020-12-03  678869
# 318  2020-12-04  690143
# 319  2020-12-05  700902
# 320  2020-12-06  710612
# 321  2020-12-07  717930
#
# [322 rows x 2 columns]
#  Currently processing New York, number 18 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.65 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5376.811, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5232.807, Time=0.52 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.32 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5374.812, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5365.799, Time=0.04 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=5101.041, Time=0.92 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.56 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.31 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=5120.146, Time=1.19 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=5086.814, Time=2.05 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=5206.148, Time=0.78 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.56 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=5087.331, Time=2.32 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=5085.616, Time=3.38 sec
#  ARIMA(2,2,1)(1,2,0)[7] intercept   : AIC=5201.174, Time=1.83 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=5.30 sec
#  ARIMA(2,2,1)(1,2,1)[7] intercept   : AIC=5126.057, Time=2.14 sec
#  ARIMA(1,2,1)(2,2,0)[7] intercept   : AIC=5085.894, Time=2.43 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.73 sec
#  ARIMA(2,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=5.68 sec
#  ARIMA(1,2,2)(2,2,0)[7] intercept   : AIC=5085.036, Time=2.75 sec
#  ARIMA(1,2,2)(1,2,0)[7] intercept   : AIC=5197.254, Time=0.97 sec
#  ARIMA(1,2,2)(2,2,1)[7] intercept   : AIC=4995.880, Time=3.39 sec
#  ARIMA(1,2,2)(1,2,1)[7] intercept   : AIC=5133.988, Time=1.99 sec
#  ARIMA(1,2,2)(2,2,2)[7] intercept   : AIC=inf, Time=5.64 sec
#  ARIMA(1,2,2)(1,2,2)[7] intercept   : AIC=inf, Time=4.91 sec
#  ARIMA(0,2,2)(2,2,1)[7] intercept   : AIC=4973.497, Time=2.81 sec
#  ARIMA(0,2,2)(1,2,1)[7] intercept   : AIC=inf, Time=1.66 sec
#  ARIMA(0,2,2)(2,2,0)[7] intercept   : AIC=5084.339, Time=1.16 sec
#  ARIMA(0,2,2)(2,2,2)[7] intercept   : AIC=5116.461, Time=4.40 sec
#  ARIMA(0,2,2)(1,2,0)[7] intercept   : AIC=5196.405, Time=0.94 sec
#  ARIMA(0,2,2)(1,2,2)[7] intercept   : AIC=inf, Time=3.99 sec
#  ARIMA(0,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(0,2,3)(2,2,1)[7] intercept   : AIC=4965.086, Time=2.77 sec
#  ARIMA(0,2,3)(1,2,1)[7] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(0,2,3)(2,2,0)[7] intercept   : AIC=5085.007, Time=1.42 sec
#  ARIMA(0,2,3)(2,2,2)[7] intercept   : AIC=5094.595, Time=5.24 sec
#  ARIMA(0,2,3)(1,2,0)[7] intercept   : AIC=5197.697, Time=0.77 sec
#  ARIMA(0,2,3)(1,2,2)[7] intercept   : AIC=5109.865, Time=4.71 sec
#  ARIMA(1,2,3)(2,2,1)[7] intercept   : AIC=5033.068, Time=3.37 sec
#  ARIMA(0,2,4)(2,2,1)[7] intercept   : AIC=5101.179, Time=2.80 sec
#  ARIMA(1,2,4)(2,2,1)[7] intercept   : AIC=inf, Time=3.32 sec
#  ARIMA(0,2,3)(2,2,1)[7]             : AIC=inf, Time=1.80 sec
#
# Best model:  ARIMA(0,2,3)(2,2,1)[7] intercept
# Total fit time: 112.958 seconds
# Done
# Guam
# ML_Data:            date  cases
# 0    2020-03-03      0
# 1    2020-03-04      0
# 2    2020-03-05      0
# 3    2020-03-06      0
# 4    2020-03-07      0
# ..          ...    ...
# 317  2020-12-03   7911
# 318  2020-12-04   7928
# 319  2020-12-05   7946
# 320  2020-12-06   7973
# 321  2020-12-07   7988
#
# [322 rows x 2 columns]
#  Currently processing Guam, number 19 of 55 states
# Performing stepwise search to minimize aic
# ...
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5100.237, Time=0.03 sec
#  ARIMA(0,2,0)(1,2,0)[7] intercept   : AIC=5061.848, Time=0.36 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(0,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(0,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.32 sec
#  ARIMA(0,2,1)(1,2,0)[7] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(1,2,1)(1,2,0)[7] intercept   : AIC=4787.312, Time=0.98 sec
#  ARIMA(1,2,1)(0,2,0)[7] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(1,2,1)(2,2,0)[7] intercept   : AIC=4696.044, Time=2.04 sec
#  ARIMA(1,2,1)(2,2,1)[7] intercept   : AIC=4607.082, Time=3.58 sec
#  ARIMA(1,2,1)(2,2,2)[7] intercept   : AIC=4667.934, Time=4.87 sec
#  ARIMA(1,2,1)(1,2,2)[7] intercept   : AIC=4682.016, Time=4.40 sec
#  ARIMA(0,2,1)(2,2,1)[7] intercept   : AIC=4563.883, Time=2.56 sec
#  ARIMA(0,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.74 sec
#  ARIMA(0,2,1)(2,2,0)[7] intercept   : AIC=4715.432, Time=1.95 sec
#  ARIMA(0,2,1)(2,2,2)[7] intercept   : AIC=inf, Time=3.22 sec
#  ARIMA(0,2,1)(1,2,2)[7] intercept   : AIC=inf, Time=5.09 sec
#  ARIMA(0,2,2)(2,2,1)[7] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=4634.596, Time=2.54 sec
#  ARIMA(1,2,2)(2,2,1)[7] intercept   : AIC=inf, Time=3.40 sec
#  ARIMA(0,2,1)(2,2,1)[7]             : AIC=inf, Time=1.26 sec
#
# Best model:  ARIMA(0,2,1)(2,2,1)[7] intercept
# Total fit time: 50.269 seconds
# Done
# New Hampshire
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03  22925
# 318  2020-12-04  23690
# 319  2020-12-05  24138
# 320  2020-12-06  24771
# 321  2020-12-07  25816
#
# [322 rows x 2 columns]
#  Currently processing New Hampshire, number 50 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.93 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3836.020, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3834.063, Time=0.02 sec
#  ARIMA(0,2,0)(1,2,0)[7] intercept   : AIC=3662.014, Time=0.33 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3603.804, Time=0.93 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(0,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3559.749, Time=1.64 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.44 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3504.541, Time=3.43 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.95 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3495.355, Time=4.15 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3549.786, Time=1.79 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.86 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.13 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3492.010, Time=5.93 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3548.644, Time=2.19 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.85 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.86 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3485.479, Time=5.05 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3547.626, Time=3.42 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=7.65 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.27 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3484.913, Time=5.62 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=3539.533, Time=4.35 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=3389.497, Time=8.77 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.47 sec
#  ARIMA(6,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=6.78 sec
#  ARIMA(6,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=4.04 sec
#  ARIMA(6,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=8.83 sec
#  ARIMA(5,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=7.57 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=6.76 sec
#
# Best model:  ARIMA(6,2,0)(2,2,1)[7] intercept
# Total fit time: 124.631 seconds
# Done
# North Dakota
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03  81111
# 318  2020-12-04  81955
# 319  2020-12-05  82510
# 320  2020-12-06  82987
# 321  2020-12-07  83348
#
# [322 rows x 2 columns]
#  Currently processing North Dakota, number 51 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.67 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4293.156, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4044.817, Time=0.40 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4291.158, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4142.725, Time=0.08 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3964.529, Time=0.86 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4070.307, Time=0.85 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3940.880, Time=2.21 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4020.047, Time=0.62 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.84 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3935.857, Time=2.33 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4013.438, Time=0.81 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.77 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3925.345, Time=2.80 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=4000.475, Time=0.99 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.42 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.91 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3926.550, Time=2.70 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.39 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.04 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.71 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=3923.332, Time=1.18 sec
#  ARIMA(4,2,0)(1,2,0)[7]             : AIC=3998.494, Time=0.49 sec
#  ARIMA(4,2,0)(2,2,1)[7]             : AIC=inf, Time=4.64 sec
#  ARIMA(4,2,0)(1,2,1)[7]             : AIC=inf, Time=1.62 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=3933.852, Time=1.01 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3924.531, Time=1.22 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=5.52 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=3.09 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=6.30 sec
#
# Best model:  ARIMA(4,2,0)(2,2,0)[7]
# Total fit time: 82.816 seconds
# Done
# Nebraska
# ML_Data:            date   cases
# 0    2020-01-21       0
# 1    2020-01-22       0
# 2    2020-01-23       0
# 3    2020-01-24       0
# 4    2020-01-25       0
# ..          ...     ...
# 317  2020-12-03  134710
# 318  2020-12-04  136349
# 319  2020-12-05  138568
# 320  2020-12-06  139834
# 321  2020-12-07  141284
#
# [322 rows x 2 columns]
#  Currently processing Nebraska, number 52 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.76 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4792.033, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=4463.915, Time=0.55 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.18 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4790.036, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4642.377, Time=0.05 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=4404.997, Time=0.87 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=4496.492, Time=1.08 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=4374.498, Time=1.60 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=4424.789, Time=1.27 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.45 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.56 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=4366.056, Time=2.11 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=4420.909, Time=0.92 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.76 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.08 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=4367.988, Time=3.27 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.40 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=4.02 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.05 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=4364.063, Time=2.06 sec
#  ARIMA(3,2,0)(1,2,0)[7]             : AIC=4418.989, Time=0.77 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=2.54 sec
#  ARIMA(3,2,0)(1,2,1)[7]             : AIC=inf, Time=1.05 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=4372.499, Time=1.21 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=4365.994, Time=2.93 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=5.56 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=inf, Time=3.59 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=3.35 sec
#
# Best model:  ARIMA(3,2,0)(2,2,0)[7]
# Total fit time: 67.522 seconds
# Done
# Maine
# ML_Data:            date  cases
# 0    2020-01-21      0
# 1    2020-01-22      0
# 2    2020-01-23      0
# 3    2020-01-24      0
# 4    2020-01-25      0
# ..          ...    ...
# 317  2020-12-03  12554
# 318  2020-12-04  12844
# 319  2020-12-05  13127
# 320  2020-12-06  13348
# 321  2020-12-07  13775
#
# [322 rows x 2 columns]
#  Currently processing Maine, number 53 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3293.903, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3203.587, Time=0.37 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.10 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3291.918, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=3279.843, Time=0.14 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3135.078, Time=0.69 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3166.236, Time=0.55 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3107.429, Time=1.39 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3171.397, Time=0.59 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.63 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3084.422, Time=3.53 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3116.371, Time=1.27 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.13 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.34 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3082.910, Time=3.72 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3116.436, Time=0.93 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.71 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.75 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3081.184, Time=4.74 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3109.751, Time=2.04 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.95 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3082.864, Time=4.60 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=3081.386, Time=6.13 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=3083.686, Time=4.30 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.05 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3079.478, Time=1.21 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=3108.118, Time=0.57 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=2.66 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=1.58 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=3081.232, Time=0.87 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=3081.152, Time=1.22 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=3079.669, Time=2.38 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=3081.996, Time=1.37 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=5.30 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 86.958 seconds
# Done
# California
# ML_Data:            date    cases
# 0    2020-01-21        0
# 1    2020-01-22        0
# 2    2020-01-23        0
# 3    2020-01-24        0
# 4    2020-01-25        1
# ..          ...      ...
# 317  2020-12-03  1293887
# 318  2020-12-04  1318139
# 319  2020-12-05  1343145
# 320  2020-12-06  1371940
# 321  2020-12-07  1399167
#
# [322 rows x 2 columns]
#  Currently processing California, number 54 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=5406.214, Time=1.63 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5721.047, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5520.979, Time=0.82 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5719.087, Time=0.03 sec
#  ARIMA(1,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.36 sec
#  ARIMA(1,2,1)(1,2,0)[7] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(1,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=2.53 sec
#  ARIMA(1,2,1)(1,2,2)[7] intercept   : AIC=inf, Time=4.36 sec
#  ARIMA(1,2,1)(0,2,0)[7] intercept   : AIC=5654.894, Time=0.18 sec
#  ARIMA(1,2,1)(0,2,2)[7] intercept   : AIC=5249.503, Time=3.19 sec
#  ARIMA(0,2,1)(0,2,2)[7] intercept   : AIC=inf, Time=3.11 sec
#  ARIMA(1,2,0)(0,2,2)[7] intercept   : AIC=inf, Time=2.29 sec
#  ARIMA(2,2,1)(0,2,2)[7] intercept   : AIC=inf, Time=4.10 sec
#  ARIMA(1,2,2)(0,2,2)[7] intercept   : AIC=inf, Time=4.94 sec
#  ARIMA(0,2,0)(0,2,2)[7] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(0,2,2)(0,2,2)[7] intercept   : AIC=inf, Time=4.34 sec
#  ARIMA(2,2,0)(0,2,2)[7] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(2,2,2)(0,2,2)[7] intercept   : AIC=inf, Time=6.24 sec
#  ARIMA(1,2,1)(0,2,2)[7]             : AIC=inf, Time=3.29 sec
#
# Best model:  ARIMA(1,2,1)(0,2,2)[7] intercept
# Total fit time: 48.539 seconds
# Done
# Tennessee
# ML_Data:            date   cases
# 0    2020-01-24       0
# 1    2020-01-25       0
# 2    2020-01-26       0
# 3    2020-01-27       0
# 4    2020-01-28       0
# ..          ...     ...
# 317  2020-12-03  379679
# 318  2020-12-04  383829
# 319  2020-12-05  388500
# 320  2020-12-06  391393
# 321  2020-12-07  399323
#
# [322 rows x 2 columns]
#  Currently processing Tennessee, number 55 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.13 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=5317.747, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=5112.975, Time=0.62 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.58 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=5315.767, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=5245.558, Time=0.06 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=5057.603, Time=1.13 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=4916.673, Time=2.82 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.56 sec
#  ARIMA(1,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=3.53 sec
#  ARIMA(1,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=2.64 sec
#  ARIMA(0,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.46 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=4978.778, Time=4.03 sec
#  ARIMA(1,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=2.60 sec
#  ARIMA(0,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=5.19 sec
#  ARIMA(1,2,0)(2,2,1)[7]             : AIC=inf, Time=1.07 sec
#
# Best model:  ARIMA(1,2,0)(2,2,1)[7] intercept
# Total fit time: 33.679 seconds
# Done

# %%
# case_results
# Out:
# []

# %%
# sarimax_case_results_data = pd.concat(case_results)
# sarimax_case_results_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4ebbb5158882> in <module>
# ----> 1 sarimax_case_results_data = pd.concat(case_results)
#       2 sarimax_case_results_data
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     329
#     330         if len(objs) == 0:
# --> 331             raise ValueError("No objects to concatenate")
#     332
#     333         if keys is None:
#
# ValueError: No objects to concatenate

# %%
# sarimax_case_results_data.index.name = 'date'
# sarimax_case_results_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-019576fc4298> in <module>
# ----> 1 sarimax_case_results_data.index.name = 'date'
#       2 sarimax_case_results_data
#
# NameError: name 'sarimax_case_results_data' is not defined

# %%
sarimax_case_prediction_data = pd.concat(case_forecasts,ignore_index=True)
sarimax_case_prediction_data
# Out:
#            date  sarimax_cases_forecasted      state
# 0    2020-12-10                  177928.0     Kansas
# 1    2020-12-11                  182488.0     Kansas
# 2    2020-12-12                  183578.0     Kansas
# 3    2020-12-13                  189707.0     Kansas
# 4    2020-12-14                  190330.0     Kansas
# ...         ...                       ...        ...
# 4945 2021-03-05                  810106.0  Tennessee
# 4946 2021-03-06                  814453.0  Tennessee
# 4947 2021-03-07                  819419.0  Tennessee
# 4948 2021-03-08                  825737.0  Tennessee
# 4949 2021-03-09                  829674.0  Tennessee
#
# [4950 rows x 3 columns]

# %%
# sarimax_case_prediction_data.set_index('date', inplace = True)
# sarimax_case_prediction_data
# Out:
#             sarimax_cases_forecasted      state
# date
# 2020-12-10                  177928.0     Kansas
# 2020-12-11                  182488.0     Kansas
# 2020-12-12                  183578.0     Kansas
# 2020-12-13                  189707.0     Kansas
# 2020-12-14                  190330.0     Kansas
# ...                              ...        ...
# 2021-03-05                  810106.0  Tennessee
# 2021-03-06                  814453.0  Tennessee
# 2021-03-07                  819419.0  Tennessee
# 2021-03-08                  825737.0  Tennessee
# 2021-03-09                  829674.0  Tennessee
#
# [4950 rows x 2 columns]

# %%
# frames = [sarimax_case_results_data, sarimax_case_prediction_data]
# sarimax_case_data = pd.concat(frames)
# sarimax_case_data=sarimax_case_data.reset_index()
# sarimax_case_data

# %%
sarimax_case_prediction_data.to_csv('Resources/sarimax_case_data.csv', index=True, date_format='%Y-%m-%d')

# %% [markdown]
# Deaths

# %%
# run cases_best_training_model on EVERY state to get a dictionary of models

death_results = []
death_forecasts = []
sarimax_death_rmse = []
death_models={}
death_splits={}
death_full_models={}

# loop through counties
i = 0 
while i < len(states_list):
    state=states_list[i]
    print(state)
    
    #get data for state     
    df= pd.read_sql(f"select * from states_deaths where state = '{state}' and NOT 'date' ISNULL and deaths != 'N'",conn)
    
    #     manipulate data as needed to run ML
    df['deaths']= pd.to_numeric(df['deaths']).astype(np.int64)
    ML_Data=df[['date', 'deaths']]
    ML_Data=ML_Data.dropna(how='any', axis=0)
#     ML_Data=ML_Data.set_index('date')
    ML_Data=ML_Data.fillna(0)
    ML_Data.head()
  
    print(f' Currently processing {state}, number {i+1} of {len(states_list)} states')
    
    #  test train split
#     end_train=today- timedelta(days=30)
#     start_test=today- timedelta(days=29)
#     train=ML_Data[:end_train]
#     test=ML_Data[start_test:]
#     train=ML_Data.deaths[:299]
#     test=ML_Data.deaths[300:]
    
#     death_splits.update({'state':states_list[i]})
#     death_splits.update({'train':train})
#     death_splits.update({'test':test})
#     #     print(splits['test'].index)
    
#     #   call fxn to determine model best params & run model with them
#     #   cases_best_training_model(ML_Data)
# #     stepwise_fit = auto_arima(train, start_p = 1, start_q = 1, 
# #                           max_p = 10, max_q = 30, m = 2,
# #                           start_P = 0, seasonal = True, 
# #                           stationary=True,
# #                           trace = True, 
# #                           error_action ='ignore',   # we don't want to know if an order does not work 
# #                           suppress_warnings = True,  # we don't want convergence warnings 
# #                           stepwise = True)           # set to stepwise     
#     stepwise_fit = auto_arima(ML_Data.cases, start_p = 1, start_q = 1, max_p = 14, max_q = 30, m = 7,
#                               start_P = 1, d=2, D=2, max_order =28, seasonal = True, 
# #                                    stationary=True,
#                               trace = True, 
#                               with_intercept=True,
#                               error_action ='ignore',   # we don't want to know if an order does not work 
#                               suppress_warnings = True,  # we don't want convergence warnings 
#                               stepwise = True) 
  
    # pull out the parameters of the best model for this county
#     x=stepwise_fit.get_params()
    
#     # override Q parameter if 0 to 1
#     so=x['seasonal_order']
# #     so_slice1=so[ :2]
# #     if so[2]==0:
# #         so=so_slice1+ (1, 2)
        
#      # runs model with best fit ARIMA params
#     model = SARIMAX(train,
#                     order = (x['order']),
#                     seasonal_order =(so),
#                     initialization='approximate_diffuse')

#     result = model.fit()
#     death_models.update({state: result})
    
#     start = len(train) 
#     end = len(train) + len(test) - 1

#     # Predictions for the test set 
#     predictions = result.predict(start, end)
#     predicted_df = pd.DataFrame(data=predictions, columns=["sarimax_deaths_predicted"])
#     predicted_df['sarimax_deaths_expected'] = test
    
#     predicted_df['sarimax_deaths_expected'] = ML_Data.deaths[299:]
#     predicted_df['date']=ML_Data.date[299:]
#     predicted_df=predicted_df.set_index('date') 
    
#     modeled_df = predicted_df.drop(columns='sarimax_deaths_expected')
    
#     #     # Calculate rmse and store
#     rmse = sqrt(mean_squared_error(predicted_df['sarimax_deaths_expected'], predicted_df['sarimax_deaths_predicted']))
#     sarimax_case_rmse.append(rmse)
    
#     # Calculate residuals
#     residuals = predicted_df['sarimax_deaths_expected'] - predicted_df['sarimax_deaths_predicted']
#     residuals_df = pd.DataFrame(data=residuals, columns=["sarimax_deaths_residuals"])
    
#     # Put everything together in dataframe  
#     results_df = modeled_df.join(residuals_df)
#     results_df['state']=state
#     death_results.append(results_df)
    
    #  get results for full dataset:
#     end_full=yesterday
#     start_full=pd.to_datetime('2020-05-01')
#     #     formodel=ML_Data[start_full:end_full]
#     formodel=ML_Data

    #   cases_best_training_model for full data
#     stepwise_fit_full = auto_arima(ML_Data.deaths, start_p = 1, start_q = 1, 
#                                    max_p = 10, max_q = 30, m = 2,
#                                    start_P = 0, seasonal = True, 
#                                    stationary=True,
#                                    trace = True, 
#                                    error_action ='ignore',   # we don't want to know if an order does not work 
#                                    suppress_warnings = True,  # we don't want convergence warnings 
#                                    stepwise = True)           # set to stepwise 
    stepwise_fit = auto_arima(ML_Data.deaths, start_p = 1, start_q = 1, 
                                   max_p = 14, max_q = 30, m = 7,
                                   start_P = 1, 
                                   d=2,
                                   D=2,
                                   max_order =28,
                                   seasonal = True, 
#                                    stationary=True,
                                   trace = True, 
                                   with_intercept=True,
                                   error_action ='ignore',   # we don't want to know if an order does not work 
                                   suppress_warnings = True,  # we don't want convergence warnings 
                                   stepwise = True) 
  
    # pull out the parameters of the best model for this county
    x_full=stepwise_fit_full.get_params()
    
    # override Q parameter if 0 to 1
    so_full=x_full['seasonal_order']
#     so_full_slice1=so_full[ :2]
#     if so_full[2]==0:
#         so_full=so_full_slice1+ (1, 2)
    
    # runs model with best fit ARIMA params
    full_model = SARIMAX(ML_Data.deaths,
                    order = (x_full['order']),
                    seasonal_order =(so_full),
                    initialization='approximate_diffuse')

    full_result = full_model.fit()
    death_full_models.update({state: full_result})
    
    # Getting 90 days for forecasts and store
    SARIMAX_forecast = round(full_result.forecast(steps = 90))
    endforecast=tomorrow + timedelta(days=90)
    idx = pd.date_range(tomorrow, endforecast, freq='d')
    SARIMAX_forecast = pd.DataFrame(list(zip(list(idx),list(SARIMAX_forecast))),
                                    columns=['date','sarimax_deaths_forecasted'])
    SARIMAX_forecast['state']=state
    death_forecasts.append(SARIMAX_forecast)
    
    i = i + 1
    print("Done")
# Out:
# Kansas
#  Currently processing Kansas, number 1 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=2182.523, Time=2.31 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2845.260, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2419.680, Time=0.49 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2843.279, Time=0.02 sec
#  ARIMA(1,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.41 sec
#  ARIMA(1,2,1)(1,2,0)[7] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(1,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=3.00 sec
#  ARIMA(1,2,1)(1,2,2)[7] intercept   : AIC=2184.884, Time=4.99 sec
#  ARIMA(1,2,1)(0,2,0)[7] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(1,2,1)(0,2,2)[7] intercept   : AIC=2213.691, Time=5.05 sec
#  ARIMA(1,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(1,2,1)(2,2,2)[7] intercept   : AIC=2185.833, Time=4.61 sec
#  ARIMA(0,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.57 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=2276.939, Time=1.04 sec
#  ARIMA(2,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.38 sec
#  ARIMA(1,2,2)(1,2,1)[7] intercept   : AIC=inf, Time=2.39 sec
#  ARIMA(0,2,0)(1,2,1)[7] intercept   : AIC=2363.732, Time=0.74 sec
#  ARIMA(0,2,2)(1,2,1)[7] intercept   : AIC=2183.100, Time=2.07 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=2254.624, Time=1.34 sec
#  ARIMA(2,2,2)(1,2,1)[7] intercept   : AIC=inf, Time=2.65 sec
#  ARIMA(1,2,1)(1,2,1)[7]             : AIC=2183.518, Time=1.03 sec
#
# Best model:  ARIMA(1,2,1)(1,2,1)[7] intercept
# Total fit time: 42.274 seconds
# Done
# Texas
#  Currently processing Texas, number 2 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=0.98 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4156.784, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3925.546, Time=0.39 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4154.784, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4057.184, Time=0.08 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3847.821, Time=0.80 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.32 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3944.166, Time=0.62 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3832.220, Time=1.35 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3910.212, Time=0.63 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3804.254, Time=1.92 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3882.948, Time=1.04 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.20 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.00 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3792.438, Time=3.03 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3868.470, Time=1.04 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.70 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3791.793, Time=2.88 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3867.480, Time=1.06 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.96 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3793.791, Time=3.24 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.58 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=4.90 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.73 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3789.799, Time=1.38 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=3865.492, Time=0.62 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=3.91 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=1.60 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=3790.443, Time=1.06 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=3791.798, Time=1.76 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=3.02 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=2.37 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=3.70 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 78.715 seconds
# Done
# Oregon
#  Currently processing Oregon, number 3 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.85 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2169.531, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1970.860, Time=0.35 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2167.531, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2079.465, Time=0.09 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1910.700, Time=0.69 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.93 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1977.161, Time=0.48 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1850.182, Time=1.04 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1916.604, Time=0.56 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.05 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.45 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1827.768, Time=1.58 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1894.081, Time=0.64 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.56 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.77 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1813.174, Time=1.75 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=1877.322, Time=0.77 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.28 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.02 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=1776.741, Time=2.20 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=1844.860, Time=0.86 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.20 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.04 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=1778.656, Time=2.40 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=1755.330, Time=3.40 sec
#  ARIMA(5,2,1)(1,2,0)[7] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(5,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=8.15 sec
#  ARIMA(5,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=3.07 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=1754.822, Time=2.66 sec
#  ARIMA(4,2,1)(1,2,0)[7] intercept   : AIC=inf, Time=2.69 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=6.38 sec
#  ARIMA(4,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.61 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=1755.370, Time=4.02 sec
#  ARIMA(4,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=8.27 sec
#  ARIMA(3,2,2)(2,2,0)[7] intercept   : AIC=1754.973, Time=6.18 sec
#  ARIMA(5,2,2)(2,2,0)[7] intercept   : AIC=1749.143, Time=4.72 sec
#  ARIMA(5,2,2)(1,2,0)[7] intercept   : AIC=inf, Time=3.19 sec
#  ARIMA(5,2,2)(2,2,1)[7] intercept   : AIC=inf, Time=9.09 sec
#  ARIMA(5,2,2)(1,2,1)[7] intercept   : AIC=inf, Time=3.46 sec
#  ARIMA(6,2,2)(2,2,0)[7] intercept   : AIC=1745.123, Time=6.63 sec
#  ARIMA(6,2,2)(1,2,0)[7] intercept   : AIC=inf, Time=3.47 sec
#  ARIMA(6,2,2)(2,2,1)[7] intercept   : AIC=inf, Time=8.70 sec
#  ARIMA(6,2,2)(1,2,1)[7] intercept   : AIC=inf, Time=3.56 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=1750.698, Time=4.36 sec
#  ARIMA(6,2,3)(2,2,0)[7] intercept   : AIC=inf, Time=8.52 sec
#  ARIMA(5,2,3)(2,2,0)[7] intercept   : AIC=1756.329, Time=7.28 sec
#  ARIMA(6,2,2)(2,2,0)[7]             : AIC=1744.348, Time=3.25 sec
#  ARIMA(6,2,2)(1,2,0)[7]             : AIC=1796.982, Time=1.69 sec
#  ARIMA(6,2,2)(2,2,1)[7]             : AIC=inf, Time=8.36 sec
#  ARIMA(6,2,2)(1,2,1)[7]             : AIC=inf, Time=3.43 sec
#  ARIMA(5,2,2)(2,2,0)[7]             : AIC=1748.205, Time=2.43 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=1749.867, Time=2.26 sec
#  ARIMA(6,2,3)(2,2,0)[7]             : AIC=inf, Time=8.42 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=1754.371, Time=1.77 sec
#  ARIMA(5,2,3)(2,2,0)[7]             : AIC=1753.303, Time=7.04 sec
#
# Best model:  ARIMA(6,2,2)(2,2,0)[7]
# Total fit time: 195.993 seconds
# Done
# Idaho
#  Currently processing Idaho, number 4 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2261.106, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1910.616, Time=0.27 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2259.114, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2109.892, Time=0.10 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1826.769, Time=0.62 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1970.770, Time=0.68 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1795.561, Time=1.32 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1889.088, Time=0.59 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1781.620, Time=1.69 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1878.552, Time=0.90 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.75 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.11 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1759.354, Time=1.83 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=1869.657, Time=1.15 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.77 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.70 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=1755.439, Time=3.04 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=1864.411, Time=1.07 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.95 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.38 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=1756.844, Time=3.22 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.79 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.18 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.01 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=1753.474, Time=0.79 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=1862.419, Time=0.40 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=3.73 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=2.11 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=1757.369, Time=0.67 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=1754.873, Time=1.01 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.91 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.02 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=5.87 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 89.586 seconds
# Done
# Alaska
#  Currently processing Alaska, number 5 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.79 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=1623.205, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1283.497, Time=0.40 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=1621.207, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=1534.829, Time=0.06 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1259.305, Time=0.52 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.54 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.33 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1348.127, Time=0.39 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1249.417, Time=0.93 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1274.611, Time=0.62 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.75 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1206.331, Time=1.29 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1245.597, Time=0.80 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.29 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.01 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1205.574, Time=1.50 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=1245.474, Time=0.96 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.14 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.49 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=1194.837, Time=2.25 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=1238.040, Time=1.33 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=8.41 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.31 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=1186.755, Time=2.68 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=1239.712, Time=2.25 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=8.75 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=4.19 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.41 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.70 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=1184.868, Time=0.88 sec
#  ARIMA(6,2,0)(1,2,0)[7]             : AIC=1237.792, Time=0.70 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=13.51 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=2.87 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=1192.946, Time=0.81 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=6.98 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.33 sec
#
# Best model:  ARIMA(6,2,0)(2,2,0)[7]
# Total fit time: 115.084 seconds
# Done
# Alabama
#  Currently processing Alabama, number 6 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2939.913, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2722.020, Time=0.34 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2937.913, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2852.874, Time=0.13 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2658.498, Time=0.64 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=0.88 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2712.264, Time=0.53 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2628.542, Time=1.19 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2688.539, Time=0.54 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2618.243, Time=1.62 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2678.418, Time=0.70 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.46 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2612.727, Time=2.19 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2676.400, Time=0.80 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.89 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2588.963, Time=3.73 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2658.314, Time=1.41 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.50 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.20 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2590.958, Time=3.70 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.94 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.36 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=16.85 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2587.020, Time=1.43 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=2656.361, Time=0.56 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=2.86 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=1.19 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2610.761, Time=0.94 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=2589.016, Time=1.28 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=7.15 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=6.73 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=7.06 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 96.616 seconds
# Done
# Oklahoma
#  Currently processing Oklahoma, number 7 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.95 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2251.581, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2043.170, Time=0.28 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2249.590, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2208.064, Time=0.10 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1992.104, Time=0.62 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.01 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2041.525, Time=0.47 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1952.928, Time=1.16 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1993.182, Time=0.52 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.24 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.42 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1942.906, Time=1.75 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1980.272, Time=0.75 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.18 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.74 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1932.581, Time=1.84 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=1969.619, Time=0.86 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.37 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.88 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=1929.766, Time=2.19 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=1969.163, Time=0.98 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.73 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=1929.990, Time=3.17 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.82 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.81 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.81 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=1927.785, Time=0.80 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=1967.199, Time=0.41 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=7.47 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=2.49 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=1930.586, Time=0.64 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=1928.021, Time=1.07 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.18 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.50 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=7.10 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 97.683 seconds
# Done
# North Carolina
#  Currently processing North Carolina, number 8 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2822.899, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2601.510, Time=0.49 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2820.899, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2762.470, Time=0.12 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2503.955, Time=0.63 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.49 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2571.033, Time=0.65 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2486.767, Time=1.64 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2566.911, Time=0.61 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.42 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2442.842, Time=2.04 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2523.085, Time=0.89 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.11 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.67 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2407.941, Time=1.94 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2485.631, Time=1.06 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.53 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.78 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2402.909, Time=3.65 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2480.010, Time=1.51 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=7.07 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2404.814, Time=5.36 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.62 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=2401.579, Time=3.70 sec
#  ARIMA(4,2,1)(1,2,0)[7] intercept   : AIC=2482.730, Time=1.68 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=7.35 sec
#  ARIMA(4,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=3.11 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.40 sec
#  ARIMA(4,2,2)(2,2,0)[7] intercept   : AIC=2403.300, Time=5.47 sec
#  ARIMA(3,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=7.67 sec
#  ARIMA(5,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=8.38 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=2399.609, Time=1.53 sec
#  ARIMA(4,2,1)(1,2,0)[7]             : AIC=2480.764, Time=0.91 sec
#  ARIMA(4,2,1)(2,2,1)[7]             : AIC=inf, Time=7.94 sec
#  ARIMA(4,2,1)(1,2,1)[7]             : AIC=inf, Time=3.01 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=4.41 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2405.948, Time=0.93 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.48 sec
#  ARIMA(4,2,2)(2,2,0)[7]             : AIC=2401.333, Time=1.60 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=2440.842, Time=0.63 sec
#  ARIMA(3,2,2)(2,2,0)[7]             : AIC=inf, Time=4.68 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2400.927, Time=1.04 sec
#  ARIMA(5,2,2)(2,2,0)[7]             : AIC=inf, Time=5.68 sec
#
# Best model:  ARIMA(4,2,1)(2,2,0)[7]
# Total fit time: 144.022 seconds
# Done
# Colorado
#  Currently processing Colorado, number 9 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2921.327, Time=0.04 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2638.068, Time=0.44 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2919.331, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2819.985, Time=0.13 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2542.447, Time=1.58 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.12 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2668.591, Time=0.68 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2506.278, Time=1.34 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2612.557, Time=0.59 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.63 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2496.316, Time=2.48 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2607.186, Time=0.97 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.94 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.02 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2498.254, Time=2.17 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.32 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=3.98 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.14 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=2494.317, Time=0.89 sec
#  ARIMA(3,2,0)(1,2,0)[7]             : AIC=2605.191, Time=0.37 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=1.60 sec
#  ARIMA(3,2,0)(1,2,1)[7]             : AIC=inf, Time=1.93 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=2504.278, Time=0.45 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2496.255, Time=0.84 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=4.04 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=inf, Time=1.79 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.92 sec
#
# Best model:  ARIMA(3,2,0)(2,2,0)[7]
# Total fit time: 53.995 seconds
# Done
# Mississippi
#  Currently processing Mississippi, number 10 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2811.193, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2604.413, Time=0.32 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2809.193, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2760.711, Time=0.13 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2523.150, Time=0.71 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.13 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2578.563, Time=0.53 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2481.531, Time=1.54 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2582.459, Time=0.56 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.86 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.99 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2443.720, Time=2.55 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2524.942, Time=0.92 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.92 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.53 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2409.005, Time=2.96 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2485.257, Time=1.27 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=8.08 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.29 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2394.720, Time=3.68 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2465.340, Time=1.28 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.38 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.50 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2396.139, Time=4.08 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=2395.544, Time=4.86 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.87 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=2396.698, Time=6.16 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2392.734, Time=0.95 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=2463.352, Time=0.46 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=5.91 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=2.16 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2407.012, Time=0.72 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=2394.153, Time=1.02 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=2393.559, Time=1.93 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.04 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=2394.712, Time=2.32 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 93.022 seconds
# Done
# Florida
#  Currently processing Florida, number 11 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3520.634, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3273.288, Time=0.34 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3518.634, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=3438.367, Time=0.11 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3200.265, Time=0.68 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.16 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3272.212, Time=0.61 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3167.314, Time=1.21 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3240.638, Time=0.64 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.32 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.88 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3136.576, Time=1.59 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3199.565, Time=0.96 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.70 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3135.431, Time=1.98 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=3192.131, Time=1.18 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.96 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.79 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=3131.538, Time=2.75 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=3183.852, Time=1.72 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.03 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.79 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=3132.639, Time=3.36 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.87 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.94 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.75 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=3129.540, Time=0.97 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=3181.852, Time=0.70 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=3.17 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=1.65 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=3133.432, Time=0.97 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=3130.641, Time=1.39 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=6.28 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=5.59 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=7.34 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 91.737 seconds
# Done
# Virgin Islands
#  Currently processing Virgin Islands, number 12 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.85 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=808.083, Time=0.06 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=501.580, Time=0.38 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=806.083, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=745.945, Time=0.13 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=451.915, Time=0.82 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.66 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.35 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=494.964, Time=0.54 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=414.290, Time=1.36 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=465.546, Time=0.59 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.58 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.05 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=405.261, Time=1.39 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=459.206, Time=0.67 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.40 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=399.380, Time=1.79 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=454.232, Time=0.89 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.62 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.42 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=386.972, Time=2.24 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=445.897, Time=1.02 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=10.38 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.39 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=388.692, Time=3.68 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.81 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=347.966, Time=7.92 sec
#  ARIMA(4,2,1)(1,2,0)[7] intercept   : AIC=inf, Time=3.29 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=8.15 sec
#  ARIMA(4,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=3.98 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.68 sec
#  ARIMA(4,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=7.00 sec
#  ARIMA(3,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=6.13 sec
#  ARIMA(5,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=8.16 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.43 sec
#
# Best model:  ARIMA(4,2,1)(2,2,0)[7] intercept
# Total fit time: 122.052 seconds
# Done
# Vermont
#  Currently processing Vermont, number 13 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=1247.919, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=999.145, Time=0.26 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.58 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=1245.923, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=1150.313, Time=0.08 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=945.384, Time=0.46 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.02 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.20 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1032.872, Time=0.38 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=907.521, Time=0.84 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=983.489, Time=0.41 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.37 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.79 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=880.937, Time=1.17 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=941.044, Time=0.54 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.88 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.96 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=874.856, Time=1.22 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=940.422, Time=0.64 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.98 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.50 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=875.837, Time=1.62 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.56 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.45 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.43 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=872.857, Time=0.58 sec
#  ARIMA(4,2,0)(1,2,0)[7]             : AIC=938.424, Time=0.33 sec
#  ARIMA(4,2,0)(2,2,1)[7]             : AIC=inf, Time=5.31 sec
#  ARIMA(4,2,0)(1,2,1)[7]             : AIC=inf, Time=1.68 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=878.938, Time=0.52 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=873.839, Time=0.73 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.95 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=3.86 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=7.38 sec
#
# Best model:  ARIMA(4,2,0)(2,2,0)[7]
# Total fit time: 83.276 seconds
# Done
# Delaware
#  Currently processing Delaware, number 14 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2633.610, Time=0.06 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2361.848, Time=0.39 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.18 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2631.610, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2553.050, Time=0.10 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2285.314, Time=0.69 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.90 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2366.998, Time=0.49 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2236.524, Time=1.42 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2331.550, Time=0.50 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.51 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2221.644, Time=1.37 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2308.656, Time=0.63 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.77 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.85 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2213.666, Time=1.59 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2298.176, Time=0.73 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.58 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2208.428, Time=2.32 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2291.064, Time=0.82 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.63 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.40 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2210.045, Time=2.55 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.77 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.78 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.33 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2206.428, Time=0.96 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=2289.064, Time=0.46 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=7.24 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=2.19 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2211.666, Time=0.64 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=2208.045, Time=1.15 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.26 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=5.35 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=6.02 sec
#
# Best model:  ARIMA(5,2,0)(2,2,0)[7]
# Total fit time: 97.322 seconds
# Done
# Northern Mariana Islands
#  Currently processing Northern Mariana Islands, number 15 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.30 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=181.489, Time=0.07 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=-151.667, Time=0.53 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.59 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=179.489, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=32.413, Time=0.18 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=-239.126, Time=1.02 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.96 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.61 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=-138.061, Time=1.59 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=-278.815, Time=2.11 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=-196.865, Time=1.08 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.49 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.91 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=-299.289, Time=2.33 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=-219.569, Time=1.23 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.96 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=-310.812, Time=3.08 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=-232.289, Time=1.31 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.93 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=-438.231, Time=6.04 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=-365.737, Time=1.92 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=-575.869, Time=6.89 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.72 sec
#  ARIMA(5,2,0)(2,2,2)[7] intercept   : AIC=inf, Time=7.68 sec
#  ARIMA(5,2,0)(1,2,2)[7] intercept   : AIC=inf, Time=3.72 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=-575.046, Time=8.10 sec
#  ARIMA(5,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(4,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=7.29 sec
#  ARIMA(6,2,1)(2,2,1)[7] intercept   : AIC=-543.428, Time=8.90 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=7.62 sec
#
# Best model:  ARIMA(5,2,0)(2,2,1)[7] intercept
# Total fit time: 109.405 seconds
# Done
# Nevada
#  Currently processing Nevada, number 16 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.72 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2635.314, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2368.329, Time=0.38 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2633.314, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2556.696, Time=0.14 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2290.114, Time=0.82 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.34 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2367.075, Time=0.74 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2240.398, Time=1.16 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2313.005, Time=0.48 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.78 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.24 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2229.834, Time=2.52 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2300.306, Time=0.85 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.77 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.91 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2204.946, Time=2.32 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2261.391, Time=0.95 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.71 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.52 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2193.329, Time=2.45 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2251.597, Time=1.04 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.78 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.40 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2195.251, Time=3.18 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.11 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.83 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.24 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2191.330, Time=0.84 sec
#  ARIMA(5,2,0)(1,2,0)[7]             : AIC=2249.598, Time=0.42 sec
#  ARIMA(5,2,0)(2,2,1)[7]             : AIC=inf, Time=5.29 sec
#  ARIMA(5,2,0)(1,2,1)[7]             : AIC=inf, Time=3.39 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2202.947, Time=0.67 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=2193.252, Time=1.00 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=2151.288, Time=3.49 sec
#  ARIMA(5,2,1)(1,2,0)[7]             : AIC=inf, Time=1.97 sec
#  ARIMA(5,2,1)(2,2,1)[7]             : AIC=inf, Time=6.49 sec
#  ARIMA(5,2,1)(1,2,1)[7]             : AIC=inf, Time=2.59 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=2150.088, Time=2.70 sec
#  ARIMA(4,2,1)(1,2,0)[7]             : AIC=inf, Time=1.83 sec
#  ARIMA(4,2,1)(2,2,1)[7]             : AIC=inf, Time=6.55 sec
#  ARIMA(4,2,1)(1,2,1)[7]             : AIC=inf, Time=3.17 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=2.92 sec
#  ARIMA(4,2,2)(2,2,0)[7]             : AIC=2151.729, Time=5.35 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=2227.839, Time=0.70 sec
#  ARIMA(3,2,2)(2,2,0)[7]             : AIC=inf, Time=3.75 sec
#  ARIMA(5,2,2)(2,2,0)[7]             : AIC=2150.765, Time=6.95 sec
#
# Best model:  ARIMA(4,2,1)(2,2,0)[7]
# Total fit time: 134.736 seconds
# Done
# Louisiana
#  Currently processing Louisiana, number 17 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3047.454, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2774.674, Time=0.50 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3045.455, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2974.297, Time=0.16 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2698.569, Time=1.21 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2767.426, Time=0.74 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2677.323, Time=1.86 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2739.969, Time=0.68 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.74 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2660.826, Time=3.14 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2717.829, Time=0.96 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.10 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2658.884, Time=3.04 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=2713.356, Time=1.09 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.44 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=2648.805, Time=4.72 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=2705.757, Time=1.18 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.88 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.21 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=2648.491, Time=3.85 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=2705.520, Time=1.54 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.69 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=8.27 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.42 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=2646.493, Time=1.23 sec
#  ARIMA(6,2,0)(1,2,0)[7]             : AIC=2703.522, Time=0.54 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=3.11 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=1.31 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=2646.807, Time=1.47 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=inf, Time=5.37 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=inf, Time=5.90 sec
#
# Best model:  ARIMA(6,2,0)(2,2,0)[7]
# Total fit time: 81.693 seconds
# Done
# New York
#  Currently processing New York, number 18 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=4139.178, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3903.121, Time=0.39 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=4137.178, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=4052.187, Time=0.09 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3817.073, Time=0.90 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3878.402, Time=0.84 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3776.961, Time=1.84 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3856.212, Time=0.72 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.67 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.10 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3778.090, Time=2.21 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=3778.210, Time=2.87 sec
#  ARIMA(1,2,1)(2,2,0)[7] intercept   : AIC=3794.336, Time=1.31 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=7.98 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=3774.962, Time=0.73 sec
#  ARIMA(2,2,0)(1,2,0)[7]             : AIC=3854.212, Time=0.37 sec
#  ARIMA(2,2,0)(2,2,1)[7]             : AIC=inf, Time=2.16 sec
#  ARIMA(2,2,0)(1,2,1)[7]             : AIC=inf, Time=1.10 sec
#  ARIMA(1,2,0)(2,2,0)[7]             : AIC=3815.073, Time=0.44 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=3776.090, Time=0.90 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=3776.210, Time=1.37 sec
#  ARIMA(1,2,1)(2,2,0)[7]             : AIC=3792.337, Time=0.64 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=5.01 sec
#
# Best model:  ARIMA(2,2,0)(2,2,0)[7]
# Total fit time: 39.217 seconds
# Done
# Guam
#  Currently processing Guam, number 19 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=1551.771, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1269.778, Time=0.26 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.88 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=1549.771, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=1428.663, Time=0.09 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1158.158, Time=0.44 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.10 sec
# ...
# Done
# New Hampshire
#  Currently processing New Hampshire, number 50 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.09 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=1867.748, Time=0.04 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1658.261, Time=0.41 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.39 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=1865.748, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=1828.010, Time=0.10 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1584.534, Time=0.55 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.24 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1623.672, Time=0.41 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1520.726, Time=0.96 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1600.986, Time=0.43 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.98 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.93 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1506.914, Time=2.09 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1590.162, Time=0.63 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.44 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1482.606, Time=1.21 sec
#  ARIMA(4,2,0)(1,2,0)[7] intercept   : AIC=1554.852, Time=0.62 sec
#  ARIMA(4,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=6.93 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.87 sec
#  ARIMA(5,2,0)(2,2,0)[7] intercept   : AIC=1458.305, Time=1.70 sec
#  ARIMA(5,2,0)(1,2,0)[7] intercept   : AIC=1521.036, Time=0.93 sec
#  ARIMA(5,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=5.38 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.58 sec
#  ARIMA(6,2,0)(2,2,0)[7] intercept   : AIC=1457.261, Time=2.32 sec
#  ARIMA(6,2,0)(1,2,0)[7] intercept   : AIC=1510.060, Time=1.22 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=8.01 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=3.66 sec
#  ARIMA(6,2,1)(2,2,0)[7] intercept   : AIC=1459.021, Time=3.64 sec
#  ARIMA(5,2,1)(2,2,0)[7] intercept   : AIC=1458.597, Time=3.84 sec
#  ARIMA(6,2,0)(2,2,0)[7]             : AIC=1455.317, Time=1.15 sec
#  ARIMA(6,2,0)(1,2,0)[7]             : AIC=1508.099, Time=0.57 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=inf, Time=7.21 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=4.07 sec
#  ARIMA(5,2,0)(2,2,0)[7]             : AIC=1456.386, Time=0.59 sec
#  ARIMA(6,2,1)(2,2,0)[7]             : AIC=1457.076, Time=1.69 sec
#  ARIMA(5,2,1)(2,2,0)[7]             : AIC=1456.666, Time=1.57 sec
#
# Best model:  ARIMA(6,2,0)(2,2,0)[7]
# Total fit time: 85.524 seconds
# Done
# North Dakota
#  Currently processing North Dakota, number 51 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.07 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2196.738, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1846.117, Time=0.36 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.96 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2194.738, Time=0.03 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2102.902, Time=0.14 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1757.660, Time=0.78 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.20 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=1856.861, Time=0.51 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=1674.507, Time=1.14 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=1737.122, Time=0.64 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.11 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=1667.695, Time=2.16 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=1735.442, Time=0.93 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=1668.645, Time=2.28 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.38 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=1661.415, Time=1.33 sec
#  ARIMA(2,2,1)(1,2,0)[7] intercept   : AIC=1730.981, Time=0.71 sec
#  ARIMA(2,2,1)(2,2,1)[7] intercept   : AIC=inf, Time=5.00 sec
#  ARIMA(2,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(1,2,1)(2,2,0)[7] intercept   : AIC=1665.896, Time=0.80 sec
#  ARIMA(2,2,2)(2,2,0)[7] intercept   : AIC=1661.604, Time=1.83 sec
#  ARIMA(1,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=2.50 sec
#  ARIMA(3,2,2)(2,2,0)[7] intercept   : AIC=inf, Time=5.50 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=1659.445, Time=0.59 sec
#  ARIMA(2,2,1)(1,2,0)[7]             : AIC=1729.022, Time=0.31 sec
#  ARIMA(2,2,1)(2,2,1)[7]             : AIC=inf, Time=2.25 sec
#  ARIMA(2,2,1)(1,2,1)[7]             : AIC=inf, Time=1.43 sec
#  ARIMA(1,2,1)(2,2,0)[7]             : AIC=1663.909, Time=0.43 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=1672.523, Time=0.38 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=3.51 sec
#  ARIMA(2,2,2)(2,2,0)[7]             : AIC=1659.633, Time=0.75 sec
#  ARIMA(1,2,0)(2,2,0)[7]             : AIC=1755.663, Time=0.30 sec
#  ARIMA(1,2,2)(2,2,0)[7]             : AIC=inf, Time=1.42 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=1665.713, Time=0.51 sec
#  ARIMA(3,2,2)(2,2,0)[7]             : AIC=inf, Time=5.12 sec
#
# Best model:  ARIMA(2,2,1)(2,2,0)[7]
# Total fit time: 66.729 seconds
# Done
# Nebraska
#  Currently processing Nebraska, number 52 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.85 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=2470.664, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2164.360, Time=0.35 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.71 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=2468.672, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2370.068, Time=0.10 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2115.106, Time=0.84 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.23 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2176.393, Time=0.47 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2081.333, Time=1.13 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2141.662, Time=0.54 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.54 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.62 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2060.567, Time=1.95 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2130.855, Time=0.85 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=4.67 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.74 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2062.268, Time=2.09 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=4.92 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=4.94 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.44 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=2058.568, Time=0.80 sec
#  ARIMA(3,2,0)(1,2,0)[7]             : AIC=2128.857, Time=0.32 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=4.09 sec
#  ARIMA(3,2,0)(1,2,1)[7]             : AIC=inf, Time=1.84 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=2079.333, Time=0.55 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2060.269, Time=0.93 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=inf, Time=4.07 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=inf, Time=3.26 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.58 sec
#
# Best model:  ARIMA(3,2,0)(2,2,0)[7]
# Total fit time: 64.515 seconds
# Done
# Maine
#  Currently processing Maine, number 53 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.74 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=1580.651, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=1280.605, Time=0.23 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=1578.659, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=1464.039, Time=0.07 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=1236.557, Time=0.38 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=1196.108, Time=1.06 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=1196.450, Time=0.45 sec
#  ARIMA(1,2,0)(2,2,2)[7] intercept   : AIC=1196.359, Time=2.15 sec
#  ARIMA(1,2,0)(1,2,2)[7] intercept   : AIC=1194.596, Time=1.81 sec
#  ARIMA(1,2,0)(0,2,2)[7] intercept   : AIC=1192.800, Time=0.84 sec
#  ARIMA(1,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(0,2,0)(0,2,2)[7] intercept   : AIC=1275.537, Time=0.61 sec
#  ARIMA(2,2,0)(0,2,2)[7] intercept   : AIC=1150.999, Time=1.01 sec
#  ARIMA(2,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(2,2,0)(1,2,2)[7] intercept   : AIC=1152.423, Time=2.64 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=1153.486, Time=0.61 sec
#  ARIMA(3,2,0)(0,2,2)[7] intercept   : AIC=1145.751, Time=1.16 sec
#  ARIMA(3,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(3,2,0)(1,2,2)[7] intercept   : AIC=1147.376, Time=3.08 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=1148.479, Time=0.77 sec
#  ARIMA(4,2,0)(0,2,2)[7] intercept   : AIC=1142.618, Time=1.47 sec
#  ARIMA(4,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(4,2,0)(1,2,2)[7] intercept   : AIC=1144.050, Time=2.39 sec
#  ARIMA(4,2,0)(1,2,1)[7] intercept   : AIC=1145.678, Time=0.93 sec
#  ARIMA(5,2,0)(0,2,2)[7] intercept   : AIC=1135.524, Time=1.60 sec
#  ARIMA(5,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(5,2,0)(1,2,2)[7] intercept   : AIC=1136.241, Time=3.50 sec
#  ARIMA(5,2,0)(1,2,1)[7] intercept   : AIC=1139.095, Time=1.06 sec
#  ARIMA(6,2,0)(0,2,2)[7] intercept   : AIC=1101.643, Time=3.14 sec
#  ARIMA(6,2,0)(0,2,1)[7] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(6,2,0)(1,2,2)[7] intercept   : AIC=1098.430, Time=4.19 sec
#  ARIMA(6,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.03 sec
#  ARIMA(6,2,0)(2,2,2)[7] intercept   : AIC=1100.203, Time=8.32 sec
#  ARIMA(6,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=7.23 sec
#  ARIMA(6,2,1)(1,2,2)[7] intercept   : AIC=1098.856, Time=6.60 sec
#  ARIMA(5,2,1)(1,2,2)[7] intercept   : AIC=1100.815, Time=5.98 sec
#  ARIMA(6,2,0)(1,2,2)[7]             : AIC=1096.736, Time=3.59 sec
#  ARIMA(6,2,0)(0,2,2)[7]             : AIC=1099.853, Time=2.38 sec
#  ARIMA(6,2,0)(1,2,1)[7]             : AIC=inf, Time=1.29 sec
#  ARIMA(6,2,0)(2,2,2)[7]             : AIC=1098.629, Time=8.41 sec
#  ARIMA(6,2,0)(0,2,1)[7]             : AIC=inf, Time=0.91 sec
#  ARIMA(6,2,0)(2,2,1)[7]             : AIC=1110.447, Time=3.58 sec
#  ARIMA(5,2,0)(1,2,2)[7]             : AIC=1134.242, Time=2.20 sec
#  ARIMA(6,2,1)(1,2,2)[7]             : AIC=1094.523, Time=6.77 sec
#  ARIMA(6,2,1)(0,2,2)[7]             : AIC=1092.736, Time=4.83 sec
#  ARIMA(6,2,1)(0,2,1)[7]             : AIC=inf, Time=2.01 sec
#  ARIMA(6,2,1)(1,2,1)[7]             : AIC=1099.674, Time=2.22 sec
#  ARIMA(5,2,1)(0,2,2)[7]             : AIC=1095.208, Time=3.14 sec
#  ARIMA(6,2,2)(0,2,2)[7]             : AIC=1094.725, Time=4.99 sec
#  ARIMA(5,2,0)(0,2,2)[7]             : AIC=1133.524, Time=1.10 sec
#  ARIMA(5,2,2)(0,2,2)[7]             : AIC=1097.688, Time=6.28 sec
#  ARIMA(6,2,1)(0,2,2)[7] intercept   : AIC=1094.366, Time=6.58 sec
#
# Best model:  ARIMA(6,2,1)(0,2,2)[7]
# Total fit time: 134.351 seconds
# Done
# California
#  Currently processing California, number 54 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3405.874, Time=0.02 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=3155.165, Time=0.34 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3403.875, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=3297.958, Time=0.13 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=3082.756, Time=0.75 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=3164.107, Time=0.60 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=3046.750, Time=1.30 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=3121.618, Time=0.60 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.67 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=3017.580, Time=1.64 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=3094.760, Time=0.66 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.29 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=3018.876, Time=2.11 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=2.53 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.86 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=3015.657, Time=0.66 sec
#  ARIMA(3,2,0)(1,2,0)[7]             : AIC=3092.808, Time=0.30 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=1.93 sec
#  ARIMA(3,2,0)(1,2,1)[7]             : AIC=inf, Time=0.85 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=3044.781, Time=0.52 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=3016.964, Time=0.89 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=2987.381, Time=3.49 sec
#  ARIMA(3,2,1)(1,2,0)[7]             : AIC=inf, Time=0.65 sec
#  ARIMA(3,2,1)(2,2,1)[7]             : AIC=inf, Time=6.90 sec
#  ARIMA(3,2,1)(1,2,1)[7]             : AIC=inf, Time=2.27 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=inf, Time=1.62 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.24 sec
#  ARIMA(3,2,2)(2,2,0)[7]             : AIC=inf, Time=4.71 sec
#  ARIMA(2,2,2)(2,2,0)[7]             : AIC=inf, Time=5.42 sec
#  ARIMA(4,2,2)(2,2,0)[7]             : AIC=inf, Time=5.78 sec
#
# Best model:  ARIMA(3,2,1)(2,2,0)[7]
# Total fit time: 69.327 seconds
# Done
# Tennessee
#  Currently processing Tennessee, number 55 of 55 states
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(1,2,1)[7] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(0,2,0)(0,2,0)[7] intercept   : AIC=3049.372, Time=0.03 sec
#  ARIMA(1,2,0)(1,2,0)[7] intercept   : AIC=2730.573, Time=0.48 sec
#  ARIMA(0,2,1)(0,2,1)[7] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(0,2,0)(0,2,0)[7]             : AIC=3047.372, Time=0.02 sec
#  ARIMA(1,2,0)(0,2,0)[7] intercept   : AIC=2947.152, Time=0.14 sec
#  ARIMA(1,2,0)(2,2,0)[7] intercept   : AIC=2665.114, Time=1.09 sec
#  ARIMA(1,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(1,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(0,2,0)(2,2,0)[7] intercept   : AIC=2753.835, Time=0.57 sec
#  ARIMA(2,2,0)(2,2,0)[7] intercept   : AIC=2604.823, Time=1.81 sec
#  ARIMA(2,2,0)(1,2,0)[7] intercept   : AIC=2698.523, Time=0.85 sec
#  ARIMA(2,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.13 sec
#  ARIMA(2,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(3,2,0)(2,2,0)[7] intercept   : AIC=2570.602, Time=3.17 sec
#  ARIMA(3,2,0)(1,2,0)[7] intercept   : AIC=2662.304, Time=1.33 sec
#  ARIMA(3,2,0)(2,2,1)[7] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(3,2,0)(1,2,1)[7] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(4,2,0)(2,2,0)[7] intercept   : AIC=2571.355, Time=4.81 sec
#  ARIMA(3,2,1)(2,2,0)[7] intercept   : AIC=2571.365, Time=3.74 sec
#  ARIMA(2,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=5.04 sec
#  ARIMA(4,2,1)(2,2,0)[7] intercept   : AIC=inf, Time=6.40 sec
#  ARIMA(3,2,0)(2,2,0)[7]             : AIC=2568.629, Time=0.87 sec
#  ARIMA(3,2,0)(1,2,0)[7]             : AIC=2660.344, Time=0.46 sec
#  ARIMA(3,2,0)(2,2,1)[7]             : AIC=inf, Time=1.89 sec
#  ARIMA(3,2,0)(1,2,1)[7]             : AIC=inf, Time=1.01 sec
#  ARIMA(2,2,0)(2,2,0)[7]             : AIC=2602.828, Time=0.46 sec
#  ARIMA(4,2,0)(2,2,0)[7]             : AIC=2569.389, Time=1.13 sec
#  ARIMA(3,2,1)(2,2,0)[7]             : AIC=2569.399, Time=0.88 sec
#  ARIMA(2,2,1)(2,2,0)[7]             : AIC=inf, Time=3.51 sec
#  ARIMA(4,2,1)(2,2,0)[7]             : AIC=inf, Time=4.70 sec
#
# Best model:  ARIMA(3,2,0)(2,2,0)[7]
# Total fit time: 56.920 seconds
# Done

# %%
# results_df

# %%
# death_results

# %%
# sarimax_death_results_data = pd.concat(death_results)
# sarimax_death_results_data

# %%
# sarimax_death_results_data.index.name = 'date'

# %%
sarimax_death_prediction_data = pd.concat(death_forecasts,ignore_index=True)
sarimax_death_prediction_data
# Out:
#            date  sarimax_deaths_forecasted      state
# 0    2020-12-10                     1860.0     Kansas
# 1    2020-12-11                     1947.0     Kansas
# 2    2020-12-12                     1958.0     Kansas
# 3    2020-12-13                     2023.0     Kansas
# 4    2020-12-14                     2035.0     Kansas
# ...         ...                        ...        ...
# 4945 2021-03-05                    16753.0  Tennessee
# 4946 2021-03-06                    17007.0  Tennessee
# 4947 2021-03-07                    17242.0  Tennessee
# 4948 2021-03-08                    17426.0  Tennessee
# 4949 2021-03-09                    17616.0  Tennessee
#
# [4950 rows x 3 columns]

# %%
# sarimax_death_prediction_data.set_index('date', inplace = True)
# sarimax_death_prediction_data

# %%
# frames = [sarimax_death_results_data, sarimax_death_prediction_data]
# sarimax_death_data = pd.concat(frames).reset_index()
# sarimax_death_data.tail(50)

# %%
sarimax_death_prediction_data.to_csv('Resources/sarimax_death_data.csv', index=True, date_format='%Y-%m-%d')

# %%
# test db
stuff= pd.read_sql(f"select * from states_cases_forecast where state = 'Texas' and NOT 'date' ISNULL",conn)

# %%
stuff
# Out:
#      id        date  sarimax_cases_forecasted  state
# 0    90  2020-12-10                 1373437.0  Texas
# 1    91  2020-12-11                 1388684.0  Texas
# 2    92  2020-12-12                 1402335.0  Texas
# 3    93  2020-12-13                 1416113.0  Texas
# 4    94  2020-12-14                 1428428.0  Texas
# ..  ...         ...                       ...    ...
# 85  175  2021-03-05                 2884011.0  Texas
# 86  176  2021-03-06                 2906229.0  Texas
# 87  177  2021-03-07                 2928586.0  Texas
# 88  178  2021-03-08                 2949079.0  Texas
# 89  179  2021-03-09                 2968830.0  Texas
#
# [90 rows x 4 columns]

# %%
# import plotly.express as px
# x= stuff.date
# y1=stuff.sarimax_cases_predicted
# y2=stuff.sarimax_cases_forecasted
# px.scatter(stuff, x=x, y=[y1, y2])
